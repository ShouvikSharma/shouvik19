# %%
1
# Out:
# Starting Spark application
# <table>
# <tr><th>ID</th><th>YARN Application ID</th><th>Kind</th><th>State</th><th>Spark UI</th><th>Driver log</th><th>User</th><th>Current session?</th></tr><tr><td>0</td><td>application_1715647822374_0001</td><td>pyspark</td><td>idle</td><td><a target="_blank" href="http://ip-10-240-119-89.us-east-2.compute.internal:20888/proxy/application_1715647822374_0001/">Link</a></td><td><a target="_blank" href="http://ip-10-240-119-118.us-east-2.compute.internal:8042/node/containerlogs/container_1715647822374_0001_01_000001/livy">Link</a></td><td>None</td><td>✔</td></tr></table>
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# SparkSession available as 'spark'.
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# 1

# %%
args = {'ENV': 'prod', 'REGION': 'us-east-2', 'account_id': '235352882622', 'PARTNER_NAME': 'avant', 'emr_details': {}, 'AIRFLOW_PATH': '/usr/local/airflow', 'SQL_BASE_PATH': '/usr/local/airflow/test', 'DREMIO_ENV': 'prod', 'PARTNER_ID': 'partner01', 'measurement_date': '2024-05-13', 'YEAR': '2024', 'MONTH': '05', 'DATE': '13', 'YYYY': '2024', 'MM': '05', 'DD': '13', 'date': '2024-05-13', 'date_time': '2024-05-13 23:06:30', 'smtp_details': {'EMAIL_FROM': 'campaign-airflow-prod@partner01.data.avant.com'}, 'vault_details': {'vault_url': 'https://vault.shared.partner01.data.avant.com', 'meta_model': 'app/campaign/meta_model/prod', 'ec2_metadata_url': 'http://169.254.169.254', 'group_role': 'airflow-role', 'ec2_role': 'avant-campaign-dev-ecs-task-role', 'emr_role': 'campaign_emr_instance_role', 'vault_meta_base_url': '{base}/latest/meta-data/iam/security-credentials/{role}', 'encryption_details': 'app/landing_zone_encryption/acxiom/2024', 'dremio_jdbc_user': 'app/dremio/jdbc_prod_sa', 'dremio_jdbc_url': 'jdbc:dremio:direct=dremio-int-prod.services.global.avant.com:31010', 'dremio_url': 'https://dremio-prod.services.global.avant.com', 'dremio_vault_path': 'user/devops/dremio/sa_prod_user', 'garden_vault_path': 'user/devops/garden/campaign_garden_scoring', 'smtp_vault_path': 'user/devops/smtp', 'neustar_vault_path': 'app/neustar', 'approval_vault_path': 'app/campaign/approval/prod'}, 'sqs_details': {'encrypt_decrypt_sqs_details': {'sqs_name': '{}_{}_{}_encrypt_decrypt_queue', 'sqs_url': 'https://sqs.us-east-2.amazonaws.com/235352882622/{}.fifo'}, 'selection_eligibility_sqs_details': {'sqs_name': '{}_{}_{}_selection_eligibility_queue', 'sqs_url': 'https://sqs.us-east-2.amazonaws.com/235352882622/{}.fifo'}, 'selection_desirability_sqs_details': {'sqs_name': '{}_{}_{}_selection_desirability_queue', 'sqs_url': 'https://sqs.us-east-2.amazonaws.com/235352882622/{}.fifo'}}, 's3_details': {'config_file_bucket': 'avantcamp-partner01-prod-common-bucket', 'config_file_names': {'parameter_data': 'common/parameters.cfg', 'feed_schema_tracker': 'common/feed_schema.cfg'}, 'campaign_input_file_prefix_history': 'campaign-user-input-files_history', 'campaign_input_file_prefix': 'campaign-user-input-files', 'campaign_input_file_name': 'campaign - User Input - Template.xlsx', 'campaign_dynamic_dag_file_prefix': 'campaign-system-input-files', 'campaign_dynamic_dag_file_name': 'campaign_dynamic_dag_config.json'}, 'schema_name': 'campaign_config', 'campaign_driver_table_name': 'campaign_driver', 'selection_group_tname': 'selection_group_rule_config', 'uow_dependency_table_name': 'uow_dependency', 'parent_config_id': '1', 'campaign_driver_config_table_name': 'campaign_driver_config', 'common_config_table_name': 'common_system_config', 'airflow_path': '/usr/local/airflow', 'state_dict': {'state_id': {1: 'started', 2: 'inprogress', 3: 'completed', 4: 'failed'}, 'message': {1: 'submitted PySpark job to EMR', 2: 'PySpark job running in EMR', 3: 'Completed PySpark job successfully'}}, 'dremio_table_details': [{'table_name': 'table_name_1', 'table_path': 'path1'}, {'table_name': 'table_name_2', 'table_path': 'path2'}], 'executor_instances': '70', 'sql_base_path': '/usr/local/airflow/sql/{}/{}/{}.sql', 'dremio_security_table_name': 'avant.prod.campaign_abc.campaign_config.campaign_dremio_masking_table', 'local_path': '/usr/local/airflow', 'campaign_type_config_id': '3', 'conf': "{'spark.executor.memoryOverhead': '5g', 'spark.driver.maxResultSize': '3g', 'spark.driver.memory': '8g'}", 'executor_memory': '26g', 'campaign_name': 'Direct Mail Remail', 'looker_url': 'https://avantstaging.looker.com/dashboards-next/465', 'campaign_run_name': '202406_001R1', 'remail_eligibility_path': 'direct_mail/remail/eligibility/10244', 'remail_ingestion_file_name': 'remail_ingestion.pq', 'remail_eligibility_file_name': 'remail_eligibility.pq', 'remail_desirability_file_name': 'direct_mail_remail_desirability.pq', 'remail_desirability_path': 'direct_mail/remail/desirability/10244', 'remail_transformation_file_name': 'remail_transformation.pq', 'remail_approval_file_name': 'remail_approval.pq', 'remail_mailed_file_path': 'direct_mail/remail_mailed/10244', 'remail_publish_file_name': 'remail_publish.csv', 'remail_eligibility_source_path': 'direct_mail/remail/eligibility_source/10244', 'remail_eligibility_source_file_name': 'direct_mail_eligibility_source.pq', 'remail_transformation_dedup_file_name': 'direct_mail_transformation.pq', 'remail_transformation_creative_file_name': 'direct_mail_transformation.pq', 'remail_transformation_creative_path': 'direct_mail/remail/creative_code_allocated/10244', 'remail_transformation_dedup_path': 'direct_mail/remail/creative_code_allocated_and_deduped_history/10244', 'remail_transformation_final_dedup_path': 'direct_mail/remail/creative_code_allocated_and_deduped_final', 'remail_publish_path': 'preapproved_records/avant/{ENV}', 'remail_acxiom_publish_file_name': 'AV_REMAIL_{batch_key}_SELECTION_{date}.csv', 'remail_acxiom_publish_path': 'acxiom/to_acxiom/{ENV}', 'feed_metadata_object': 'common/feed_metadata.cfg', 'uow_dependency_object': 'common/uow_dependency.cfg', 'uow_error_object': 'common/uow_error.cfg', 'config_file_bucket': 'avantcamp-prod-common-bucket', 'config_file_name': 'common/feed_metadata.cfg', 'remail_file_path': 'direct_mail/remail_mailed/10244', 'parameter_config_file': 'common/parameters.cfg', 'acxiom_bucket': 'avant-partner01-landing', 'avant_acxiom_bucket': 'avant-acxiom', 'remail_amount_publish_file_name': 'direct_mail_remail_10244_{campaign_run_id}_{date}.csv', 'data_lake_bucket': 'avant-data-lake-ingest', 'publish_bucket': 'avantcamp-partner01-prod-publish-bucket', 'common_bucket': 'avantcamp-partner01-prod-common-bucket', 'exception_bucket': 'avantcamp-partner01-prod-exception-bucket', 'log_bucket': 'avantcamp-partner01-prod-log-bucket', 'selection_bucket': 'avantcamp-partner01-prod-selection-bucket', 'approval_bucket': 'avantcamp-partner01-prod-approval-bucket', 'transient_bucket': 'avantcamp-partner01-prod-transient-bucket', 'ingestion_bucket': 'avantcamp-partner01-prod-ingestion-bucket', 'transform_bucket': 'avantcamp-partner01-prod-transform-bucket', 'scoring_bucket': 'avantcamp-partner01-prod-score-bucket', 'call_logs_amount_publish_path': 'landing/bpo/{ENV}/call_logs', 'bpo_amount_publish_bucket': 'amount-{PARTNER_NAME}-prd-data-lake-ingest', 'call_interval_amount_publish_path': 'landing/bpo/{ENV}/call_interval', 'emails_amount_publish_path': 'landing/bpo/{ENV}/emails', 'qa_amount_publish_path': 'landing/bpo/{ENV}/qa', 'agent_interval_amount_publish_path': 'landing/bpo/{ENV}/agent_interval', 'dremio_ingestion_file_path': '{source_file_type}/{YYYY}/{MM}/{DD}', 'dremio_ingestion_file_name': 'bpo_{source_file_type}_10244_{campaign_run_id}_{date}.{file_format}', 'emails_rename_full_source_path': 'emails/{YYYY}/{MM}/{DD}/bpo_emails_10244_{campaign_run_id}_{date}.{file_format}', 'ivr_call_logs_rename_full_source_path': 'ivr_call_logs/{YYYY}/{MM}/{DD}/bpo_ivr_call_logs_10244_{campaign_run_id}_{date}.{file_format}', 'qa_rename_full_source_path': 'qa/{YYYY}/{MM}/{DD}/bpo_qa_10244_{campaign_run_id}_{date}.{file_format}', 'call_logs_rename_full_source_path': 'call_logs/{YYYY}/{MM}/{DD}/bpo_call_logs_10244_{campaign_run_id}_{date}.{file_format}', 'agent_interval_rename_full_source_path': 'agent_interval/{YYYY}/{MM}/{DD}/bpo_agent_interval_10244_{campaign_run_id}_{date}.{file_format}', 'call_interval_rename_full_source_path': 'call_interval/{YYYY}/{MM}/{DD}/bpo_call_interval_10244_{campaign_run_id}_{date}.{file_format}', 'emails_rename_file_name': 'bpo_emails_10244_{campaign_run_id}_{date}.{file_format}', 'ivr_call_logs_rename_file_name': 'bpo_ivr_call_logs_10244_{campaign_run_id}_{date}.{file_format}', 'qa_rename_file_name': 'bpo_qa_10244_{campaign_run_id}_{date}.{file_format}', 'call_logs_rename_file_name': 'bpo_call_logs_10244_{campaign_run_id}_{date}.{file_format}', 'agent_interval_rename_file_name': 'bpo_agent_interval_10244_{campaign_run_id}_{date}.{file_format}', 'call_interval_rename_file_name': 'bpo_call_interval_10244_{campaign_run_id}_{date}.{file_format}', 'remail_eligiblity_path': 'direct_mail/remail/eligibility/10244', 'remail_eligiblity_file_name': 'direct_mail_remail_eligibility.pq', 'remail_selection_dedup_path': 'direct_mail/remail/selection_dedup/10244', 'remail_mailed_latest_send': 'direct_mail/remail_mailed_latest_send', 'args_dremio_jdbc_user_prod': 'app/dremio/jdbc_prod_sa', 'args_dremio_url_prod': 'https://dremio-prod.services.global.avant.com', 'publish_eloan_bucket': 'avantcamp-partner02-prod-publish-bucket', 'transform_eloan_bucket': 'avantcamp-partner02-prod-transform-bucket', 'ingestion_eloan_bucket': 'avantcamp-partner02-prod-ingestion-bucket', 'args_dremio_vault_path_prod': 'user/devops/dremio/sa_prod_user', 'args_dremio_jdbc_url_prod': 'jdbc:dremio:direct=dremio-int-prod.services.global.avant.com:31010', 'direct_mail_selected_path': 's3://avantcamp-partner01-prod-transform-bucket/avant/direct_mail/first_mail/creative_code_allocated_and_deduped_final/*', 'td_dlds_raw_bucket': 'avantdlds-partner03-prod-raw-bucket', 'ingestion_td_bucket': 'avantcamp-partner03-prod-ingestion-bucket', 'td_dlds_transform_bucket': 'avantdlds-partner03-prod-transform-bucket', 'transform_td_bucket': 'avantcamp-partner03-prod-transform-bucket', 'campaign_batch_id': '10244', 'campaign_run_id': '1', 'dremio_data': {7: {'transformation': [{'dremio_config_id': 4, 'campaign_type_config_id': 3, 'stage_id': 7, 'sequence': 2, 'module_config_type': 'transformation', 're_create': '0.0', 'sql_type': 'select', 'pds': 'avantcamp-{PARTNER_ID}-{DREMIO_ENV}.avantcamp-{PARTNER_ID}-{ENV}-transform-bucket.{PARTNER_NAME}.direct_mail.remail.creative_code_allocated_and_deduped_history', 'intermediate_vds': '{PARTNER_NAME}.{ENV}.intermediate.dw.dw_orig.direct_mail_remail_selected_by_send', 'intermediate_vds_sql': 'select * from avantcamp-{PARTNER_ID}-{DREMIO_ENV}.avantcamp-{PARTNER_ID}-{ENV}-transform-bucket.{PARTNER_NAME}.direct_mail.remail.creative_code_allocated_and_deduped_history', 'final_vds': '{PARTNER_NAME}.{ENV}.dw.dw_orig.direct_mail_remail_selected_by_send', 'final_vds_sql': '', 'created_by': 'avantadmin', 'created_date': '2021-06-04', 'is_active_flag': True}, {'dremio_config_id': 3, 'campaign_type_config_id': 3, 'stage_id': 7, 'sequence': 1, 'module_config_type': 'transformation', 're_create': '0.0', 'sql_type': 'select', 'pds': 'avantcamp-{PARTNER_ID}-{DREMIO_ENV}.avantcamp-{PARTNER_ID}-{ENV}-transform-bucket.{PARTNER_NAME}.direct_mail.remail.creative_code_allocated_and_deduped_final', 'intermediate_vds': '{PARTNER_NAME}.{ENV}.intermediate.dw.dw_orig.direct_mail_remail_selected', 'intermediate_vds_sql': 'select * from avantcamp-{PARTNER_ID}-{DREMIO_ENV}.avantcamp-{PARTNER_ID}-{ENV}-transform-bucket.{PARTNER_NAME}.direct_mail.remail.creative_code_allocated_and_deduped_final', 'final_vds': '{PARTNER_NAME}.{ENV}.dw.dw_orig.direct_mail_remail_selected', 'final_vds_sql': '', 'created_by': 'avantadmin', 'created_date': '2021-06-04', 'is_active_flag': True}]}, 9: {'ingestion': [{'dremio_config_id': 20, 'campaign_type_config_id': 3, 'stage_id': 9, 'sequence': 1, 'module_config_type': 'ingestion', 're_create': '0.0', 'sql_type': 'select', 'pds': 'avantcamp-{PARTNER_ID}-{DREMIO_ENV}.avantcamp-{PARTNER_ID}-{ENV}-ingestion-bucket.{PARTNER_NAME}.direct_mail.remail_mailed', 'intermediate_vds': '{PARTNER_NAME}.{ENV}.intermediate.dw.dw_orig.direct_mail_remail_mailed_by_send', 'intermediate_vds_sql': 'select * from avantcamp-{PARTNER_ID}-{DREMIO_ENV}.avantcamp-{PARTNER_ID}-{ENV}-ingestion-bucket.{PARTNER_NAME}.direct_mail.remail_mailed', 'final_vds': '{PARTNER_NAME}.{ENV}.dw.dw_orig.direct_mail_remail_mailed_by_send', 'final_vds_sql': '', 'created_by': 'avantadmin', 'created_date': '2021-06-23', 'is_active_flag': True}, {'dremio_config_id': 21, 'campaign_type_config_id': 3, 'stage_id': 9, 'sequence': 2, 'module_config_type': 'ingestion', 're_create': '0.0', 'sql_type': 'select', 'pds': 'avantcamp-{PARTNER_ID}-{DREMIO_ENV}.avantcamp-{PARTNER_ID}-{ENV}-ingestion-bucket.{PARTNER_NAME}.direct_mail.remail_mailed_latest_send', 'intermediate_vds': '{PARTNER_NAME}.{ENV}.intermediate.dw.dw_orig.direct_mail_remail_mailed', 'intermediate_vds_sql': 'select * from avantcamp-{PARTNER_ID}-{DREMIO_ENV}.avantcamp-{PARTNER_ID}-{ENV}-ingestion-bucket.{PARTNER_NAME}.direct_mail.remail_mailed_latest_send', 'final_vds': '{PARTNER_NAME}.{ENV}.dw.dw_orig.direct_mail_remail_mailed', 'final_vds_sql': '', 'created_by': 'avantadmin', 'created_date': '2021-06-23', 'is_active_flag': True}]}}, 'from_date': '2024-05-12', 'to_date': '2024-05-13', 'current_date': '2024-05-13', '7': {'selection': {'eligibility': {'source_path': 's3://avantcamp-partner01-prod-ingestion-bucket/avant/direct_mail/remail/eligibility_source/10244/direct_mail_eligibility_source.pq', 'target_path': 's3://avantcamp-partner01-prod-selection-bucket/avant/direct_mail/remail/eligibility/10244/direct_mail_remail_eligibility.pq'}, 'desirability': {'source_path': 's3://avantcamp-partner01-prod-selection-bucket/avant/direct_mail/remail/eligibility/10244/direct_mail_remail_eligibility.pq', 'target_path': 's3://avantcamp-partner01-prod-selection-bucket/avant/direct_mail/remail/desirability/10244/direct_mail_remail_desirability.pq'}, 'selection_dedup': {'source_path': 's3://avantcamp-partner01-prod-selection-bucket/avant/direct_mail/remail/desirability/10244/direct_mail_remail_desirability.pq', 'target_path': 's3://avantcamp-partner01-prod-selection-bucket/avant/direct_mail/remail/selection_dedup/10244/direct_mail_remail_desirability.pq'}}, 'transformation': {'creative_code_allocation': {'source_path': 's3://avantcamp-partner01-prod-selection-bucket/avant/direct_mail/remail/selection_dedup/10244/direct_mail_remail_desirability.pq', 'target_path': 's3://avantcamp-partner01-prod-transform-bucket/avant/direct_mail/remail/creative_code_allocated/10244/direct_mail_transformation.pq'}, 'dedup_after_creative_code_allocation': {'source_path': 's3://avantcamp-partner01-prod-transform-bucket/avant/direct_mail/remail/creative_code_allocated/10244/direct_mail_transformation.pq', 'target_path': 's3://avantcamp-partner01-prod-transform-bucket/avant/direct_mail/remail/creative_code_allocated_and_deduped_history/10244/direct_mail_transformation.pq', 'approval_target_path': 's3://avantcamp-partner01-prod-transform-bucket/avant/direct_mail/remail/creative_code_allocated_and_deduped_final/direct_mail_transformation.pq'}}}, '9': {'publish': [{'source_path': 's3://avantcamp-partner01-prod-transform-bucket/avant/direct_mail/remail_mailed/10244/remail_transformation.pq', 'target_path': 's3://avant-acxiom/preapproved_records/avant/{ENV}'}]}, 'scoring_file_path': 's3://avantcamp-partner01-prod-score-bucket/avant/direct_mail/first_mail/scoring/10046/direct_mail_scoring.pq', 'direct_mail_first_mail_transformation': 's3://avantcamp-partner01-prod-ingestion-bucket/avant/direct_mail/mailed/10046/direct_mail_ingestion.pq', 'acxiom_joined_with_scoring_file_ingestion': 's3://avantcamp-partner01-prod-ingestion-bucket/avant/direct_mail/remail/eligibility_source/10244/direct_mail_eligibility_source.pq', 'remail_mailed_file_ingestion': 's3://avantcamp-partner01-prod-ingestion-bucket/avant/direct_mail/remail_mailed/10244/remail_ingestion.pq', 'remail_parquet_ingestion': 'avant/direct_mail/remail_mailed/10244/remail_ingestion.pq', 'remail_mailed_ingestion': 's3://avantcamp-partner01-prod-ingestion-bucket/avant/direct_mail/remail_mailed/10244/remail_ingestion.pq', 'remail_mailed_latest_send_ingestion': 's3://avantcamp-partner01-prod-ingestion-bucket/avant/direct_mail/remail_mailed_latest_send/remail_ingestion.pq', 'acxiom_data_transformation': 's3://avantcamp-partner01-prod-ingestion-bucket/avant/direct_mail/remail_mailed/10244/remail_ingestion.pq', 'remail_transformation': 's3://avantcamp-partner01-prod-transform-bucket/avant/direct_mail/remail_mailed/10244/remail_transformation.pq', 'remail_deduped_final': 's3://avantcamp-partner01-prod-transform-bucket/avant/direct_mail/remail/creative_code_allocated_and_deduped_final/direct_mail_transformation.pq', 'remail_publish': 's3://avantcamp-partner01-prod-publish-bucket/avant/direct_mail/remail_mailed/10244/remail_publish.csv', 'direct_mail_remail_publish_file_name': 'acxiom/to_acxiom/{ENV}/AV_REMAIL_{batch_key}_SELECTION_{date}.csv', 'scoring_endpoint': '/api/tasks/R-syberia-scoring-master/runs/2198384', 'dag_name': 'Direct_Mail_Remail_3_2_selection', 'stage_id': '7', 'marketing_selection': False, 'batch_key': '202406', 'common_service_name': 'Direct_Mail_Remail_3_2_selection', 'campaign_driver_config_id': 35092, 'module_config_type': 'remail_source_generation', 'transformation_type': None, 'campaign_component_run_id': 266178}
campaign_config = {'campaign_driver_id': 7921, 'campaign_type_config_id': 3, 'module_config_type_id': 3, 'module_config_type': 'campaign_type_config', 'stage_id': 1, 'sequence_number': 1, 'created_by': 'avantadmin', 'created_date': '2020-12-03', 'is_active_flag': True, 'config': {'campaign_type_config_id': 3, 'name': 'Remail', 'description': 'direct mail remail', 'created_by': 'avantadmin', 'created_date': '2020-12-03', 'is_active_flag': True}, 'campaign_config_jsonb': {'1': {'campaign_type_config': {'campaign_driver_id': 7921, 'campaign_type_config_id': 3, 'module_config_type_id': 3, 'module_config_type': 'campaign_type_config', 'stage_id': 1, 'sequence_number': 1, 'created_by': 'avantadmin', 'created_date': '2020-12-03', 'is_active_flag': True, 'config': {'campaign_type_config_id': 3, 'name': 'Remail', 'description': 'direct mail remail', 'created_by': 'avantadmin', 'created_date': '2020-12-03', 'is_active_flag': True}}, 'approval_config': [{'campaign_driver_id': 7922, 'module_config_type_id': 1, 'module_config_type': 'approval_config', 'stage_id': 1, 'sequence_number': 2, 'created_by': 'avantadmin', 'created_date': '2021-06-23', 'is_active_flag': True, 'config': {'approval_config_id': 1, 'email_address': '\tcampaign-dev@avant.com', 'role': 'pipeline_alert', 'alert_type': 'notification', 'created_by': 'avantadmin', 'created_date': '2021-06-23', 'is_active_flag': True, 'description': ''}}, {'campaign_driver_id': 7923, 'module_config_type_id': 2, 'module_config_type': 'approval_config', 'stage_id': 1, 'sequence_number': 3, 'created_by': 'avantadmin', 'created_date': '2021-06-23', 'is_active_flag': True, 'config': {'approval_config_id': 2, 'email_address': '\tcampaign-dev@avant.com', 'role': 'pipeline_alert', 'alert_type': 'error_alert', 'created_by': 'avantadmin', 'created_date': '2021-06-23', 'is_active_flag': True, 'description': ''}}]}, '7': {'selection_group_config': [{'campaign_driver_id': 7924, 'module_config_type_id': 480, 'module_config_type': 'selection_group_config', 'stage_id': 7, 'sequence_number': 1, 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'description': 'Card Remail Eligibility - January 2022', 'credit_policy': '', 'product_cd': 'cc', 'inquiry_code': 'F2E8W005', 'selection_group_type': 'eligibility', 'parent_selection_group_config_id': None, 'eligibility_config': [{'selection_group_rule_config_id': 1815, 'selection_group_config_id': 480, 'sequence_number': 1, 'selection_criteria_type': 'eligibility', 'rule_type': 'select', 'rule_condition': '>=', 'description': 'card global response cut', 'rule_value_type': 'decimal', 'attribute_name': 'cc_response_200_score', 'attribute_id': '', 'sql_query': 'cc_response_200_score >= 0.0', 'rule_value': '0.0', 'created_by': 'avantadmin', 'created_date': '2021-12-07', 'is_active_flag': True, 'config': 'select * from {0} where cc_response_200_score >= 0.0'}], 'eligibility_config_id': [480]}, {'campaign_driver_id': 7925, 'module_config_type_id': 2069, 'module_config_type': 'selection_group_config', 'stage_id': 7, 'sequence_number': 2, 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'description': '$0 Established - RG 1 - 550-619 - PS - APR 35% - Non-Reward - Up to $3000', 'credit_policy': '', 'product_cd': 'cc', 'inquiry_code': 'F2E8W005', 'selection_group_type': 'desirability', 'parent_selection_group_config_id': ['480'], 'eligibility_config': [{'selection_group_rule_config_id': 1815, 'selection_group_config_id': 480, 'sequence_number': 1, 'selection_criteria_type': 'eligibility', 'rule_type': 'select', 'rule_condition': '>=', 'description': 'card global response cut', 'rule_value_type': 'decimal', 'attribute_name': 'cc_response_200_score', 'attribute_id': '', 'sql_query': 'cc_response_200_score >= 0.0', 'rule_value': '0.0', 'created_by': 'avantadmin', 'created_date': '2021-12-07', 'is_active_flag': True, 'config': 'select * from {0} where cc_response_200_score >= 0.0'}], 'desirability_config': [{'selection_group_rule_config_id': 4952, 'selection_group_config_id': 2069, 'sequence_number': 1, 'selection_criteria_type': 'desirability', 'rule_type': 'custom', 'rule_condition': 'custom', 'description': '$0 Established - RG 1 - 550-619 - PS - APR 35% - Non-Reward - Up to $3000', 'rule_value_type': 'custom', 'attribute_name': 'cc_response_200_score,cc_response_300_score,creative_type', 'attribute_id': '', 'sql_query': "((cc_response_300_score>=0.0042 and cc_response_300_score >=0.0085) or (cc_response_300_score < 0.0042 and cc_response_200_score >=0.0027)) and creative_type in ('185_403_2050')", 'rule_value': "((cc_response_300_score>=0.0042 and cc_response_300_score >=0.0085) or (cc_response_300_score < 0.0042 and cc_response_200_score >=0.0027)) and creative_type in ('185_403_2050')", 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'config': "select * from {0} where ((cc_response_300_score>=0.0042 and cc_response_300_score >=0.0085) or (cc_response_300_score < 0.0042 and cc_response_200_score >=0.0027)) and creative_type in ('185_403_2050')"}], 'desirability_config_id': [2069]}, {'campaign_driver_id': 7926, 'module_config_type_id': 2070, 'module_config_type': 'selection_group_config', 'stage_id': 7, 'sequence_number': 3, 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'description': '$0 Established - RG 1 - 620-680 - PS - APR 29% - Non-Reward - Up to $3000', 'credit_policy': '', 'product_cd': 'cc', 'inquiry_code': 'F2E8W005', 'selection_group_type': 'desirability', 'parent_selection_group_config_id': ['480'], 'eligibility_config': [{'selection_group_rule_config_id': 1815, 'selection_group_config_id': 480, 'sequence_number': 1, 'selection_criteria_type': 'eligibility', 'rule_type': 'select', 'rule_condition': '>=', 'description': 'card global response cut', 'rule_value_type': 'decimal', 'attribute_name': 'cc_response_200_score', 'attribute_id': '', 'sql_query': 'cc_response_200_score >= 0.0', 'rule_value': '0.0', 'created_by': 'avantadmin', 'created_date': '2021-12-07', 'is_active_flag': True, 'config': 'select * from {0} where cc_response_200_score >= 0.0'}], 'desirability_config': [{'selection_group_rule_config_id': 4953, 'selection_group_config_id': 2070, 'sequence_number': 1, 'selection_criteria_type': 'desirability', 'rule_type': 'custom', 'rule_condition': 'custom', 'description': '$0 Established - RG 1 - 620-680 - PS - APR 29% - Non-Reward - Up to $3000', 'rule_value_type': 'custom', 'attribute_name': 'cc_response_200_score,cc_response_300_score,creative_type', 'attribute_id': '', 'sql_query': "((cc_response_300_score>=0.0068 and cc_response_300_score >=0.0126) or (cc_response_300_score < 0.0068 and cc_response_200_score >=0.0021)) and creative_type in ('185_402_2051')", 'rule_value': "((cc_response_300_score>=0.0068 and cc_response_300_score >=0.0126) or (cc_response_300_score < 0.0068 and cc_response_200_score >=0.0021)) and creative_type in ('185_402_2051')", 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'config': "select * from {0} where ((cc_response_300_score>=0.0068 and cc_response_300_score >=0.0126) or (cc_response_300_score < 0.0068 and cc_response_200_score >=0.0021)) and creative_type in ('185_402_2051')"}], 'desirability_config_id': [2070]}, {'campaign_driver_id': 7927, 'module_config_type_id': 2071, 'module_config_type': 'selection_group_config', 'stage_id': 7, 'sequence_number': 4, 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'description': '$0 Established - RG 1 - 620-680 - PS - APR 29% - 2% Reward - Up to $3000', 'credit_policy': '', 'product_cd': 'cc', 'inquiry_code': 'F2E8W005', 'selection_group_type': 'desirability', 'parent_selection_group_config_id': ['480'], 'eligibility_config': [{'selection_group_rule_config_id': 1815, 'selection_group_config_id': 480, 'sequence_number': 1, 'selection_criteria_type': 'eligibility', 'rule_type': 'select', 'rule_condition': '>=', 'description': 'card global response cut', 'rule_value_type': 'decimal', 'attribute_name': 'cc_response_200_score', 'attribute_id': '', 'sql_query': 'cc_response_200_score >= 0.0', 'rule_value': '0.0', 'created_by': 'avantadmin', 'created_date': '2021-12-07', 'is_active_flag': True, 'config': 'select * from {0} where cc_response_200_score >= 0.0'}], 'desirability_config': [{'selection_group_rule_config_id': 4954, 'selection_group_config_id': 2071, 'sequence_number': 1, 'selection_criteria_type': 'desirability', 'rule_type': 'custom', 'rule_condition': 'custom', 'description': '$0 Established - RG 1 - 620-680 - PS - APR 29% - 2% Reward - Up to $3000', 'rule_value_type': 'custom', 'attribute_name': 'cc_response_200_score,cc_response_300_score,creative_type', 'attribute_id': '', 'sql_query': "((cc_response_300_score>=0.0068 and cc_response_300_score >=0.0126) or (cc_response_300_score < 0.0068 and cc_response_200_score >=0.0021)) and creative_type in ('185_406_2051')", 'rule_value': "((cc_response_300_score>=0.0068 and cc_response_300_score >=0.0126) or (cc_response_300_score < 0.0068 and cc_response_200_score >=0.0021)) and creative_type in ('185_406_2051')", 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'config': "select * from {0} where ((cc_response_300_score>=0.0068 and cc_response_300_score >=0.0126) or (cc_response_300_score < 0.0068 and cc_response_200_score >=0.0021)) and creative_type in ('185_406_2051')"}], 'desirability_config_id': [2071]}, {'campaign_driver_id': 7928, 'module_config_type_id': 2072, 'module_config_type': 'selection_group_config', 'stage_id': 7, 'sequence_number': 5, 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'description': '$0 Established - RG 2 - 550-619 - PS - APR 35% - Non-Reward - Up to $3000', 'credit_policy': '', 'product_cd': 'cc', 'inquiry_code': 'F2E8W005', 'selection_group_type': 'desirability', 'parent_selection_group_config_id': ['480'], 'eligibility_config': [{'selection_group_rule_config_id': 1815, 'selection_group_config_id': 480, 'sequence_number': 1, 'selection_criteria_type': 'eligibility', 'rule_type': 'select', 'rule_condition': '>=', 'description': 'card global response cut', 'rule_value_type': 'decimal', 'attribute_name': 'cc_response_200_score', 'attribute_id': '', 'sql_query': 'cc_response_200_score >= 0.0', 'rule_value': '0.0', 'created_by': 'avantadmin', 'created_date': '2021-12-07', 'is_active_flag': True, 'config': 'select * from {0} where cc_response_200_score >= 0.0'}], 'desirability_config': [{'selection_group_rule_config_id': 4955, 'selection_group_config_id': 2072, 'sequence_number': 1, 'selection_criteria_type': 'desirability', 'rule_type': 'custom', 'rule_condition': 'custom', 'description': '$0 Established - RG 2 - 550-619 - PS - APR 35% - Non-Reward - Up to $3000', 'rule_value_type': 'custom', 'attribute_name': 'cc_response_200_score,cc_response_300_score,creative_type', 'attribute_id': '', 'sql_query': "((cc_response_300_score>=0.0043 and cc_response_300_score >=0.0089) or (cc_response_300_score < 0.0043 and cc_response_200_score >=0.0028)) and creative_type in ('185_403_2052')", 'rule_value': "((cc_response_300_score>=0.0043 and cc_response_300_score >=0.0089) or (cc_response_300_score < 0.0043 and cc_response_200_score >=0.0028)) and creative_type in ('185_403_2052')", 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'config': "select * from {0} where ((cc_response_300_score>=0.0043 and cc_response_300_score >=0.0089) or (cc_response_300_score < 0.0043 and cc_response_200_score >=0.0028)) and creative_type in ('185_403_2052')"}], 'desirability_config_id': [2072]}, {'campaign_driver_id': 7929, 'module_config_type_id': 2073, 'module_config_type': 'selection_group_config', 'stage_id': 7, 'sequence_number': 6, 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'description': '$0 Established - RG 2 - 620-680 - PS - APR 29% - Non-Reward - Up to $3000', 'credit_policy': '', 'product_cd': 'cc', 'inquiry_code': 'F2E8W005', 'selection_group_type': 'desirability', 'parent_selection_group_config_id': ['480'], 'eligibility_config': [{'selection_group_rule_config_id': 1815, 'selection_group_config_id': 480, 'sequence_number': 1, 'selection_criteria_type': 'eligibility', 'rule_type': 'select', 'rule_condition': '>=', 'description': 'card global response cut', 'rule_value_type': 'decimal', 'attribute_name': 'cc_response_200_score', 'attribute_id': '', 'sql_query': 'cc_response_200_score >= 0.0', 'rule_value': '0.0', 'created_by': 'avantadmin', 'created_date': '2021-12-07', 'is_active_flag': True, 'config': 'select * from {0} where cc_response_200_score >= 0.0'}], 'desirability_config': [{'selection_group_rule_config_id': 4956, 'selection_group_config_id': 2073, 'sequence_number': 1, 'selection_criteria_type': 'desirability', 'rule_type': 'custom', 'rule_condition': 'custom', 'description': '$0 Established - RG 2 - 620-680 - PS - APR 29% - Non-Reward - Up to $3000', 'rule_value_type': 'custom', 'attribute_name': 'cc_response_200_score,cc_response_300_score,creative_type', 'attribute_id': '', 'sql_query': "((cc_response_300_score>=0.0065 and cc_response_300_score >=0.012) or (cc_response_300_score < 0.0065 and cc_response_200_score >=0.0154)) and creative_type in ('185_402_2053')", 'rule_value': "((cc_response_300_score>=0.0065 and cc_response_300_score >=0.012) or (cc_response_300_score < 0.0065 and cc_response_200_score >=0.0154)) and creative_type in ('185_402_2053')", 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'config': "select * from {0} where ((cc_response_300_score>=0.0065 and cc_response_300_score >=0.012) or (cc_response_300_score < 0.0065 and cc_response_200_score >=0.0154)) and creative_type in ('185_402_2053')"}], 'desirability_config_id': [2073]}, {'campaign_driver_id': 7930, 'module_config_type_id': 2074, 'module_config_type': 'selection_group_config', 'stage_id': 7, 'sequence_number': 7, 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'description': '$0 Established - RG 2 - 620-680 - PS - APR 29% - 2% Reward - Up to $3000', 'credit_policy': '', 'product_cd': 'cc', 'inquiry_code': 'F2E8W005', 'selection_group_type': 'desirability', 'parent_selection_group_config_id': ['480'], 'eligibility_config': [{'selection_group_rule_config_id': 1815, 'selection_group_config_id': 480, 'sequence_number': 1, 'selection_criteria_type': 'eligibility', 'rule_type': 'select', 'rule_condition': '>=', 'description': 'card global response cut', 'rule_value_type': 'decimal', 'attribute_name': 'cc_response_200_score', 'attribute_id': '', 'sql_query': 'cc_response_200_score >= 0.0', 'rule_value': '0.0', 'created_by': 'avantadmin', 'created_date': '2021-12-07', 'is_active_flag': True, 'config': 'select * from {0} where cc_response_200_score >= 0.0'}], 'desirability_config': [{'selection_group_rule_config_id': 4957, 'selection_group_config_id': 2074, 'sequence_number': 1, 'selection_criteria_type': 'desirability', 'rule_type': 'custom', 'rule_condition': 'custom', 'description': '$0 Established - RG 2 - 620-680 - PS - APR 29% - 2% Reward - Up to $3000', 'rule_value_type': 'custom', 'attribute_name': 'cc_response_200_score,cc_response_300_score,creative_type', 'attribute_id': '', 'sql_query': "((cc_response_300_score>=0.0065 and cc_response_300_score >=0.0121) or (cc_response_300_score < 0.0065 and cc_response_200_score >=0.0153)) and creative_type in ('185_406_2053')", 'rule_value': "((cc_response_300_score>=0.0065 and cc_response_300_score >=0.0121) or (cc_response_300_score < 0.0065 and cc_response_200_score >=0.0153)) and creative_type in ('185_406_2053')", 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'config': "select * from {0} where ((cc_response_300_score>=0.0065 and cc_response_300_score >=0.0121) or (cc_response_300_score < 0.0065 and cc_response_200_score >=0.0153)) and creative_type in ('185_406_2053')"}], 'desirability_config_id': [2074]}, {'campaign_driver_id': 7931, 'module_config_type_id': 2075, 'module_config_type': 'selection_group_config', 'stage_id': 7, 'sequence_number': 8, 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'description': '$0 Established - RG 3-1 - 550-619 - PS - APR 35% - Non-Reward - Up to $3000', 'credit_policy': '', 'product_cd': 'cc', 'inquiry_code': 'F2E8W005', 'selection_group_type': 'desirability', 'parent_selection_group_config_id': ['480'], 'eligibility_config': [{'selection_group_rule_config_id': 1815, 'selection_group_config_id': 480, 'sequence_number': 1, 'selection_criteria_type': 'eligibility', 'rule_type': 'select', 'rule_condition': '>=', 'description': 'card global response cut', 'rule_value_type': 'decimal', 'attribute_name': 'cc_response_200_score', 'attribute_id': '', 'sql_query': 'cc_response_200_score >= 0.0', 'rule_value': '0.0', 'created_by': 'avantadmin', 'created_date': '2021-12-07', 'is_active_flag': True, 'config': 'select * from {0} where cc_response_200_score >= 0.0'}], 'desirability_config': [{'selection_group_rule_config_id': 4958, 'selection_group_config_id': 2075, 'sequence_number': 1, 'selection_criteria_type': 'desirability', 'rule_type': 'custom', 'rule_condition': 'custom', 'description': '$0 Established - RG 3-1 - 550-619 - PS - APR 35% - Non-Reward - Up to $3000', 'rule_value_type': 'custom', 'attribute_name': 'cc_response_200_score,cc_response_300_score,creative_type', 'attribute_id': '', 'sql_query': "((cc_response_300_score>=0.006 and cc_response_300_score >=0.0126) or (cc_response_300_score < 0.006 and cc_response_200_score >=0.0057)) and creative_type in ('185_403_2054')", 'rule_value': "((cc_response_300_score>=0.006 and cc_response_300_score >=0.0126) or (cc_response_300_score < 0.006 and cc_response_200_score >=0.0057)) and creative_type in ('185_403_2054')", 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'config': "select * from {0} where ((cc_response_300_score>=0.006 and cc_response_300_score >=0.0126) or (cc_response_300_score < 0.006 and cc_response_200_score >=0.0057)) and creative_type in ('185_403_2054')"}], 'desirability_config_id': [2075]}, {'campaign_driver_id': 7932, 'module_config_type_id': 2076, 'module_config_type': 'selection_group_config', 'stage_id': 7, 'sequence_number': 9, 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'description': '$0 Established - RG 3-1 - 620-680 - PS - APR 35% - Non-Reward - Up to $3000', 'credit_policy': '', 'product_cd': 'cc', 'inquiry_code': 'F2E8W005', 'selection_group_type': 'desirability', 'parent_selection_group_config_id': ['480'], 'eligibility_config': [{'selection_group_rule_config_id': 1815, 'selection_group_config_id': 480, 'sequence_number': 1, 'selection_criteria_type': 'eligibility', 'rule_type': 'select', 'rule_condition': '>=', 'description': 'card global response cut', 'rule_value_type': 'decimal', 'attribute_name': 'cc_response_200_score', 'attribute_id': '', 'sql_query': 'cc_response_200_score >= 0.0', 'rule_value': '0.0', 'created_by': 'avantadmin', 'created_date': '2021-12-07', 'is_active_flag': True, 'config': 'select * from {0} where cc_response_200_score >= 0.0'}], 'desirability_config': [{'selection_group_rule_config_id': 4959, 'selection_group_config_id': 2076, 'sequence_number': 1, 'selection_criteria_type': 'desirability', 'rule_type': 'custom', 'rule_condition': 'custom', 'description': '$0 Established - RG 3-1 - 620-680 - PS - APR 35% - Non-Reward - Up to $3000', 'rule_value_type': 'custom', 'attribute_name': 'cc_response_200_score,cc_response_300_score,creative_type', 'attribute_id': '', 'sql_query': "((cc_response_300_score>=0.007 and cc_response_300_score >=0.014) or (cc_response_300_score < 0.007 and cc_response_200_score >=0.0036)) and creative_type in ('185_403_2055')", 'rule_value': "((cc_response_300_score>=0.007 and cc_response_300_score >=0.014) or (cc_response_300_score < 0.007 and cc_response_200_score >=0.0036)) and creative_type in ('185_403_2055')", 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'config': "select * from {0} where ((cc_response_300_score>=0.007 and cc_response_300_score >=0.014) or (cc_response_300_score < 0.007 and cc_response_200_score >=0.0036)) and creative_type in ('185_403_2055')"}], 'desirability_config_id': [2076]}, {'campaign_driver_id': 7933, 'module_config_type_id': 2077, 'module_config_type': 'selection_group_config', 'stage_id': 7, 'sequence_number': 10, 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'description': '$0/$39$75 Established - $0 AMF Test - RG 3-2 - 550-619 - ITA - APR 35% - Non-Reward - Up to $3000', 'credit_policy': '', 'product_cd': 'cc', 'inquiry_code': 'F2E8W005', 'selection_group_type': 'desirability', 'parent_selection_group_config_id': ['480'], 'eligibility_config': [{'selection_group_rule_config_id': 1815, 'selection_group_config_id': 480, 'sequence_number': 1, 'selection_criteria_type': 'eligibility', 'rule_type': 'select', 'rule_condition': '>=', 'description': 'card global response cut', 'rule_value_type': 'decimal', 'attribute_name': 'cc_response_200_score', 'attribute_id': '', 'sql_query': 'cc_response_200_score >= 0.0', 'rule_value': '0.0', 'created_by': 'avantadmin', 'created_date': '2021-12-07', 'is_active_flag': True, 'config': 'select * from {0} where cc_response_200_score >= 0.0'}], 'desirability_config': [{'selection_group_rule_config_id': 4960, 'selection_group_config_id': 2077, 'sequence_number': 1, 'selection_criteria_type': 'desirability', 'rule_type': 'custom', 'rule_condition': 'custom', 'description': '$0/$39$75 Established - $0 AMF Test - RG 3-2 - 550-619 - ITA - APR 35% - Non-Reward - Up to $3000', 'rule_value_type': 'custom', 'attribute_name': 'cc_response_200_score,cc_response_300_score,creative_type', 'attribute_id': '', 'sql_query': "((cc_response_300_score>=0.0132 and cc_response_300_score >=0.0227) or (cc_response_300_score < 0.0132 and cc_response_200_score >=0.0729)) and creative_type in ('185_403_2056')", 'rule_value': "((cc_response_300_score>=0.0132 and cc_response_300_score >=0.0227) or (cc_response_300_score < 0.0132 and cc_response_200_score >=0.0729)) and creative_type in ('185_403_2056')", 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'config': "select * from {0} where ((cc_response_300_score>=0.0132 and cc_response_300_score >=0.0227) or (cc_response_300_score < 0.0132 and cc_response_200_score >=0.0729)) and creative_type in ('185_403_2056')"}], 'desirability_config_id': [2077]}, {'campaign_driver_id': 7934, 'module_config_type_id': 2078, 'module_config_type': 'selection_group_config', 'stage_id': 7, 'sequence_number': 11, 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'description': '$0/$39/$75 Established - $39 AMF Test - RG 3-2 - 550-619 - PS - APR 35% - 1% Reward - Up to $1500', 'credit_policy': '', 'product_cd': 'cc', 'inquiry_code': 'F2E8W005', 'selection_group_type': 'desirability', 'parent_selection_group_config_id': ['480'], 'eligibility_config': [{'selection_group_rule_config_id': 1815, 'selection_group_config_id': 480, 'sequence_number': 1, 'selection_criteria_type': 'eligibility', 'rule_type': 'select', 'rule_condition': '>=', 'description': 'card global response cut', 'rule_value_type': 'decimal', 'attribute_name': 'cc_response_200_score', 'attribute_id': '', 'sql_query': 'cc_response_200_score >= 0.0', 'rule_value': '0.0', 'created_by': 'avantadmin', 'created_date': '2021-12-07', 'is_active_flag': True, 'config': 'select * from {0} where cc_response_200_score >= 0.0'}], 'desirability_config': [{'selection_group_rule_config_id': 4961, 'selection_group_config_id': 2078, 'sequence_number': 1, 'selection_criteria_type': 'desirability', 'rule_type': 'custom', 'rule_condition': 'custom', 'description': '$0/$39/$75 Established - $39 AMF Test - RG 3-2 - 550-619 - PS - APR 35% - 1% Reward - Up to $1500', 'rule_value_type': 'custom', 'attribute_name': 'cc_response_200_score,cc_response_300_score,creative_type', 'attribute_id': '', 'sql_query': "((cc_response_300_score>=0.0132 and cc_response_300_score >=0.0223) or (cc_response_300_score < 0.0132 and cc_response_200_score >=0.072)) and creative_type in ('185_384_2056')", 'rule_value': "((cc_response_300_score>=0.0132 and cc_response_300_score >=0.0223) or (cc_response_300_score < 0.0132 and cc_response_200_score >=0.072)) and creative_type in ('185_384_2056')", 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'config': "select * from {0} where ((cc_response_300_score>=0.0132 and cc_response_300_score >=0.0223) or (cc_response_300_score < 0.0132 and cc_response_200_score >=0.072)) and creative_type in ('185_384_2056')"}], 'desirability_config_id': [2078]}, {'campaign_driver_id': 7935, 'module_config_type_id': 2079, 'module_config_type': 'selection_group_config', 'stage_id': 7, 'sequence_number': 12, 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'description': '$0/$39/$75 Established - $75 AMF Test - RG 3-2 - 550-619 - PS - APR 35% - 1% Reward - Up to $1000', 'credit_policy': '', 'product_cd': 'cc', 'inquiry_code': 'F2E8W005', 'selection_group_type': 'desirability', 'parent_selection_group_config_id': ['480'], 'eligibility_config': [{'selection_group_rule_config_id': 1815, 'selection_group_config_id': 480, 'sequence_number': 1, 'selection_criteria_type': 'eligibility', 'rule_type': 'select', 'rule_condition': '>=', 'description': 'card global response cut', 'rule_value_type': 'decimal', 'attribute_name': 'cc_response_200_score', 'attribute_id': '', 'sql_query': 'cc_response_200_score >= 0.0', 'rule_value': '0.0', 'created_by': 'avantadmin', 'created_date': '2021-12-07', 'is_active_flag': True, 'config': 'select * from {0} where cc_response_200_score >= 0.0'}], 'desirability_config': [{'selection_group_rule_config_id': 4962, 'selection_group_config_id': 2079, 'sequence_number': 1, 'selection_criteria_type': 'desirability', 'rule_type': 'custom', 'rule_condition': 'custom', 'description': '$0/$39/$75 Established - $75 AMF Test - RG 3-2 - 550-619 - PS - APR 35% - 1% Reward - Up to $1000', 'rule_value_type': 'custom', 'attribute_name': 'cc_response_200_score,cc_response_300_score,creative_type', 'attribute_id': '', 'sql_query': "((cc_response_300_score>=0.0132 and cc_response_300_score >=0.0227) or (cc_response_300_score < 0.0132 and cc_response_200_score >=0.072)) and creative_type in ('185_382_2056')", 'rule_value': "((cc_response_300_score>=0.0132 and cc_response_300_score >=0.0227) or (cc_response_300_score < 0.0132 and cc_response_200_score >=0.072)) and creative_type in ('185_382_2056')", 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'config': "select * from {0} where ((cc_response_300_score>=0.0132 and cc_response_300_score >=0.0227) or (cc_response_300_score < 0.0132 and cc_response_200_score >=0.072)) and creative_type in ('185_382_2056')"}], 'desirability_config_id': [2079]}, {'campaign_driver_id': 7936, 'module_config_type_id': 2080, 'module_config_type': 'selection_group_config', 'stage_id': 7, 'sequence_number': 13, 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'description': '$0/$39/$75 Established - $0 AMF Test - RG 3-2 - 620-680 - ITA - APR 35% - TM=0 - Non-Reward - Up to $3000', 'credit_policy': '', 'product_cd': 'cc', 'inquiry_code': 'F2E8W005', 'selection_group_type': 'desirability', 'parent_selection_group_config_id': ['480'], 'eligibility_config': [{'selection_group_rule_config_id': 1815, 'selection_group_config_id': 480, 'sequence_number': 1, 'selection_criteria_type': 'eligibility', 'rule_type': 'select', 'rule_condition': '>=', 'description': 'card global response cut', 'rule_value_type': 'decimal', 'attribute_name': 'cc_response_200_score', 'attribute_id': '', 'sql_query': 'cc_response_200_score >= 0.0', 'rule_value': '0.0', 'created_by': 'avantadmin', 'created_date': '2021-12-07', 'is_active_flag': True, 'config': 'select * from {0} where cc_response_200_score >= 0.0'}], 'desirability_config': [{'selection_group_rule_config_id': 4963, 'selection_group_config_id': 2080, 'sequence_number': 1, 'selection_criteria_type': 'desirability', 'rule_type': 'custom', 'rule_condition': 'custom', 'description': '$0/$39/$75 Established - $0 AMF Test - RG 3-2 - 620-680 - ITA - APR 35% - TM=0 - Non-Reward - Up to $3000', 'rule_value_type': 'custom', 'attribute_name': 'cc_response_200_score,cc_response_300_score,creative_type', 'attribute_id': '', 'sql_query': "((cc_response_300_score>=0.0165 and cc_response_300_score >=0.0272) or (cc_response_300_score < 0.0165 and cc_response_200_score >=0.0063)) and creative_type in ('185_403_2057')", 'rule_value': "((cc_response_300_score>=0.0165 and cc_response_300_score >=0.0272) or (cc_response_300_score < 0.0165 and cc_response_200_score >=0.0063)) and creative_type in ('185_403_2057')", 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'config': "select * from {0} where ((cc_response_300_score>=0.0165 and cc_response_300_score >=0.0272) or (cc_response_300_score < 0.0165 and cc_response_200_score >=0.0063)) and creative_type in ('185_403_2057')"}], 'desirability_config_id': [2080]}, {'campaign_driver_id': 7937, 'module_config_type_id': 2081, 'module_config_type': 'selection_group_config', 'stage_id': 7, 'sequence_number': 14, 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'description': '$0/$39/$75 Established - $39 AMF Test - RG 3-2 - 620-680 - PS - APR 35% - TM=0 - 1% Reward - Up to $1500', 'credit_policy': '', 'product_cd': 'cc', 'inquiry_code': 'F2E8W005', 'selection_group_type': 'desirability', 'parent_selection_group_config_id': ['480'], 'eligibility_config': [{'selection_group_rule_config_id': 1815, 'selection_group_config_id': 480, 'sequence_number': 1, 'selection_criteria_type': 'eligibility', 'rule_type': 'select', 'rule_condition': '>=', 'description': 'card global response cut', 'rule_value_type': 'decimal', 'attribute_name': 'cc_response_200_score', 'attribute_id': '', 'sql_query': 'cc_response_200_score >= 0.0', 'rule_value': '0.0', 'created_by': 'avantadmin', 'created_date': '2021-12-07', 'is_active_flag': True, 'config': 'select * from {0} where cc_response_200_score >= 0.0'}], 'desirability_config': [{'selection_group_rule_config_id': 4964, 'selection_group_config_id': 2081, 'sequence_number': 1, 'selection_criteria_type': 'desirability', 'rule_type': 'custom', 'rule_condition': 'custom', 'description': '$0/$39/$75 Established - $39 AMF Test - RG 3-2 - 620-680 - PS - APR 35% - TM=0 - 1% Reward - Up to $1500', 'rule_value_type': 'custom', 'attribute_name': 'cc_response_200_score,cc_response_300_score,creative_type', 'attribute_id': '', 'sql_query': "((cc_response_300_score>=0.0165 and cc_response_300_score >=0.0271) or (cc_response_300_score < 0.0165 and cc_response_200_score >=0.0057)) and creative_type in ('185_384_2057')", 'rule_value': "((cc_response_300_score>=0.0165 and cc_response_300_score >=0.0271) or (cc_response_300_score < 0.0165 and cc_response_200_score >=0.0057)) and creative_type in ('185_384_2057')", 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'config': "select * from {0} where ((cc_response_300_score>=0.0165 and cc_response_300_score >=0.0271) or (cc_response_300_score < 0.0165 and cc_response_200_score >=0.0057)) and creative_type in ('185_384_2057')"}], 'desirability_config_id': [2081]}, {'campaign_driver_id': 7938, 'module_config_type_id': 2082, 'module_config_type': 'selection_group_config', 'stage_id': 7, 'sequence_number': 15, 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'description': '$0/$39/$75 Established - $75 AMF Test - RG 3-2 - 620-680 - PS - APR 35% - TM=0 - 1% Reward - Up to $1000', 'credit_policy': '', 'product_cd': 'cc', 'inquiry_code': 'F2E8W005', 'selection_group_type': 'desirability', 'parent_selection_group_config_id': ['480'], 'eligibility_config': [{'selection_group_rule_config_id': 1815, 'selection_group_config_id': 480, 'sequence_number': 1, 'selection_criteria_type': 'eligibility', 'rule_type': 'select', 'rule_condition': '>=', 'description': 'card global response cut', 'rule_value_type': 'decimal', 'attribute_name': 'cc_response_200_score', 'attribute_id': '', 'sql_query': 'cc_response_200_score >= 0.0', 'rule_value': '0.0', 'created_by': 'avantadmin', 'created_date': '2021-12-07', 'is_active_flag': True, 'config': 'select * from {0} where cc_response_200_score >= 0.0'}], 'desirability_config': [{'selection_group_rule_config_id': 4965, 'selection_group_config_id': 2082, 'sequence_number': 1, 'selection_criteria_type': 'desirability', 'rule_type': 'custom', 'rule_condition': 'custom', 'description': '$0/$39/$75 Established - $75 AMF Test - RG 3-2 - 620-680 - PS - APR 35% - TM=0 - 1% Reward - Up to $1000', 'rule_value_type': 'custom', 'attribute_name': 'cc_response_200_score,cc_response_300_score,creative_type', 'attribute_id': '', 'sql_query': "((cc_response_300_score>=0.0165 and cc_response_300_score >=0.0274) or (cc_response_300_score < 0.0165 and cc_response_200_score >=0.0058)) and creative_type in ('185_382_2057')", 'rule_value': "((cc_response_300_score>=0.0165 and cc_response_300_score >=0.0274) or (cc_response_300_score < 0.0165 and cc_response_200_score >=0.0058)) and creative_type in ('185_382_2057')", 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'config': "select * from {0} where ((cc_response_300_score>=0.0165 and cc_response_300_score >=0.0274) or (cc_response_300_score < 0.0165 and cc_response_200_score >=0.0058)) and creative_type in ('185_382_2057')"}], 'desirability_config_id': [2082]}, {'campaign_driver_id': 7939, 'module_config_type_id': 2083, 'module_config_type': 'selection_group_config', 'stage_id': 7, 'sequence_number': 16, 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'description': '$0/$39/$75 Established - $0 AMF Test - RG 3-2 - 620-680 - ITA - APR 35% - TM 1-3 - Non-Reward - Up to $3000', 'credit_policy': '', 'product_cd': 'cc', 'inquiry_code': 'F2E8W005', 'selection_group_type': 'desirability', 'parent_selection_group_config_id': ['480'], 'eligibility_config': [{'selection_group_rule_config_id': 1815, 'selection_group_config_id': 480, 'sequence_number': 1, 'selection_criteria_type': 'eligibility', 'rule_type': 'select', 'rule_condition': '>=', 'description': 'card global response cut', 'rule_value_type': 'decimal', 'attribute_name': 'cc_response_200_score', 'attribute_id': '', 'sql_query': 'cc_response_200_score >= 0.0', 'rule_value': '0.0', 'created_by': 'avantadmin', 'created_date': '2021-12-07', 'is_active_flag': True, 'config': 'select * from {0} where cc_response_200_score >= 0.0'}], 'desirability_config': [{'selection_group_rule_config_id': 4966, 'selection_group_config_id': 2083, 'sequence_number': 1, 'selection_criteria_type': 'desirability', 'rule_type': 'custom', 'rule_condition': 'custom', 'description': '$0/$39/$75 Established - $0 AMF Test - RG 3-2 - 620-680 - ITA - APR 35% - TM 1-3 - Non-Reward - Up to $3000', 'rule_value_type': 'custom', 'attribute_name': 'cc_response_200_score,cc_response_300_score,creative_type', 'attribute_id': '', 'sql_query': "((cc_response_300_score>=0.0117 and cc_response_300_score >=0.0191) or (cc_response_300_score < 0.0117 and cc_response_200_score >=0.0666)) and creative_type in ('185_403_2058')", 'rule_value': "((cc_response_300_score>=0.0117 and cc_response_300_score >=0.0191) or (cc_response_300_score < 0.0117 and cc_response_200_score >=0.0666)) and creative_type in ('185_403_2058')", 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'config': "select * from {0} where ((cc_response_300_score>=0.0117 and cc_response_300_score >=0.0191) or (cc_response_300_score < 0.0117 and cc_response_200_score >=0.0666)) and creative_type in ('185_403_2058')"}], 'desirability_config_id': [2083]}, {'campaign_driver_id': 7940, 'module_config_type_id': 2084, 'module_config_type': 'selection_group_config', 'stage_id': 7, 'sequence_number': 17, 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'description': '$0/$39/$75 Established - $39 AMF Test - RG 3-2 - 620-680 - PS - APR 35% - TM 1-3 - 1% Reward - Up to $1500', 'credit_policy': '', 'product_cd': 'cc', 'inquiry_code': 'F2E8W005', 'selection_group_type': 'desirability', 'parent_selection_group_config_id': ['480'], 'eligibility_config': [{'selection_group_rule_config_id': 1815, 'selection_group_config_id': 480, 'sequence_number': 1, 'selection_criteria_type': 'eligibility', 'rule_type': 'select', 'rule_condition': '>=', 'description': 'card global response cut', 'rule_value_type': 'decimal', 'attribute_name': 'cc_response_200_score', 'attribute_id': '', 'sql_query': 'cc_response_200_score >= 0.0', 'rule_value': '0.0', 'created_by': 'avantadmin', 'created_date': '2021-12-07', 'is_active_flag': True, 'config': 'select * from {0} where cc_response_200_score >= 0.0'}], 'desirability_config': [{'selection_group_rule_config_id': 4967, 'selection_group_config_id': 2084, 'sequence_number': 1, 'selection_criteria_type': 'desirability', 'rule_type': 'custom', 'rule_condition': 'custom', 'description': '$0/$39/$75 Established - $39 AMF Test - RG 3-2 - 620-680 - PS - APR 35% - TM 1-3 - 1% Reward - Up to $1500', 'rule_value_type': 'custom', 'attribute_name': 'cc_response_200_score,cc_response_300_score,creative_type', 'attribute_id': '', 'sql_query': "((cc_response_300_score>=0.0117 and cc_response_300_score >=0.0193) or (cc_response_300_score < 0.0117 and cc_response_200_score >=0.0688)) and creative_type in ('185_384_2058')", 'rule_value': "((cc_response_300_score>=0.0117 and cc_response_300_score >=0.0193) or (cc_response_300_score < 0.0117 and cc_response_200_score >=0.0688)) and creative_type in ('185_384_2058')", 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'config': "select * from {0} where ((cc_response_300_score>=0.0117 and cc_response_300_score >=0.0193) or (cc_response_300_score < 0.0117 and cc_response_200_score >=0.0688)) and creative_type in ('185_384_2058')"}], 'desirability_config_id': [2084]}, {'campaign_driver_id': 7941, 'module_config_type_id': 2085, 'module_config_type': 'selection_group_config', 'stage_id': 7, 'sequence_number': 18, 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'description': '$0/$39/$75 Established - $75 AMF Test - RG 3-2 - 620-680 - PS - APR 35% - TM 1-3 - 1% Reward - Up to $1000', 'credit_policy': '', 'product_cd': 'cc', 'inquiry_code': 'F2E8W005', 'selection_group_type': 'desirability', 'parent_selection_group_config_id': ['480'], 'eligibility_config': [{'selection_group_rule_config_id': 1815, 'selection_group_config_id': 480, 'sequence_number': 1, 'selection_criteria_type': 'eligibility', 'rule_type': 'select', 'rule_condition': '>=', 'description': 'card global response cut', 'rule_value_type': 'decimal', 'attribute_name': 'cc_response_200_score', 'attribute_id': '', 'sql_query': 'cc_response_200_score >= 0.0', 'rule_value': '0.0', 'created_by': 'avantadmin', 'created_date': '2021-12-07', 'is_active_flag': True, 'config': 'select * from {0} where cc_response_200_score >= 0.0'}], 'desirability_config': [{'selection_group_rule_config_id': 4968, 'selection_group_config_id': 2085, 'sequence_number': 1, 'selection_criteria_type': 'desirability', 'rule_type': 'custom', 'rule_condition': 'custom', 'description': '$0/$39/$75 Established - $75 AMF Test - RG 3-2 - 620-680 - PS - APR 35% - TM 1-3 - 1% Reward - Up to $1000', 'rule_value_type': 'custom', 'attribute_name': 'cc_response_200_score,cc_response_300_score,creative_type', 'attribute_id': '', 'sql_query': "((cc_response_300_score>=0.0117 and cc_response_300_score >=0.0191) or (cc_response_300_score < 0.0117 and cc_response_200_score >=0.0683)) and creative_type in ('185_382_2058')", 'rule_value': "((cc_response_300_score>=0.0117 and cc_response_300_score >=0.0191) or (cc_response_300_score < 0.0117 and cc_response_200_score >=0.0683)) and creative_type in ('185_382_2058')", 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'config': "select * from {0} where ((cc_response_300_score>=0.0117 and cc_response_300_score >=0.0191) or (cc_response_300_score < 0.0117 and cc_response_200_score >=0.0683)) and creative_type in ('185_382_2058')"}], 'desirability_config_id': [2085]}, {'campaign_driver_id': 7942, 'module_config_type_id': 2086, 'module_config_type': 'selection_group_config', 'stage_id': 7, 'sequence_number': 19, 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'description': '$0/$39/$75 Established - $0 AMF Test - RG 3-2 - 620-680 - ITA - APR 35% - TM>3 - Non-Reward - Up to $3000', 'credit_policy': '', 'product_cd': 'cc', 'inquiry_code': 'F2E8W005', 'selection_group_type': 'desirability', 'parent_selection_group_config_id': ['480'], 'eligibility_config': [{'selection_group_rule_config_id': 1815, 'selection_group_config_id': 480, 'sequence_number': 1, 'selection_criteria_type': 'eligibility', 'rule_type': 'select', 'rule_condition': '>=', 'description': 'card global response cut', 'rule_value_type': 'decimal', 'attribute_name': 'cc_response_200_score', 'attribute_id': '', 'sql_query': 'cc_response_200_score >= 0.0', 'rule_value': '0.0', 'created_by': 'avantadmin', 'created_date': '2021-12-07', 'is_active_flag': True, 'config': 'select * from {0} where cc_response_200_score >= 0.0'}], 'desirability_config': [{'selection_group_rule_config_id': 4969, 'selection_group_config_id': 2086, 'sequence_number': 1, 'selection_criteria_type': 'desirability', 'rule_type': 'custom', 'rule_condition': 'custom', 'description': '$0/$39/$75 Established - $0 AMF Test - RG 3-2 - 620-680 - ITA - APR 35% - TM>3 - Non-Reward - Up to $3000', 'rule_value_type': 'custom', 'attribute_name': 'cc_response_200_score,cc_response_300_score,creative_type', 'attribute_id': '', 'sql_query': "((cc_response_300_score>=0.0121 and cc_response_300_score >=0.0234) or (cc_response_300_score < 0.0121 and cc_response_200_score >=0.0838)) and creative_type in ('185_403_2059')", 'rule_value': "((cc_response_300_score>=0.0121 and cc_response_300_score >=0.0234) or (cc_response_300_score < 0.0121 and cc_response_200_score >=0.0838)) and creative_type in ('185_403_2059')", 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'config': "select * from {0} where ((cc_response_300_score>=0.0121 and cc_response_300_score >=0.0234) or (cc_response_300_score < 0.0121 and cc_response_200_score >=0.0838)) and creative_type in ('185_403_2059')"}], 'desirability_config_id': [2086]}, {'campaign_driver_id': 7943, 'module_config_type_id': 2087, 'module_config_type': 'selection_group_config', 'stage_id': 7, 'sequence_number': 20, 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'description': '$0/$39/$75 Established - $39 AMF Test - RG 3-2 - 620-680 - PS - APR 35% - TM>3 - 1% Reward - Up to $1500', 'credit_policy': '', 'product_cd': 'cc', 'inquiry_code': 'F2E8W005', 'selection_group_type': 'desirability', 'parent_selection_group_config_id': ['480'], 'eligibility_config': [{'selection_group_rule_config_id': 1815, 'selection_group_config_id': 480, 'sequence_number': 1, 'selection_criteria_type': 'eligibility', 'rule_type': 'select', 'rule_condition': '>=', 'description': 'card global response cut', 'rule_value_type': 'decimal', 'attribute_name': 'cc_response_200_score', 'attribute_id': '', 'sql_query': 'cc_response_200_score >= 0.0', 'rule_value': '0.0', 'created_by': 'avantadmin', 'created_date': '2021-12-07', 'is_active_flag': True, 'config': 'select * from {0} where cc_response_200_score >= 0.0'}], 'desirability_config': [{'selection_group_rule_config_id': 4970, 'selection_group_config_id': 2087, 'sequence_number': 1, 'selection_criteria_type': 'desirability', 'rule_type': 'custom', 'rule_condition': 'custom', 'description': '$0/$39/$75 Established - $39 AMF Test - RG 3-2 - 620-680 - PS - APR 35% - TM>3 - 1% Reward - Up to $1500', 'rule_value_type': 'custom', 'attribute_name': 'cc_response_200_score,cc_response_300_score,creative_type', 'attribute_id': '', 'sql_query': "((cc_response_300_score>=0.0121 and cc_response_300_score >=0.0235) or (cc_response_300_score < 0.0121 and cc_response_200_score >=0.0863)) and creative_type in ('185_384_2059')", 'rule_value': "((cc_response_300_score>=0.0121 and cc_response_300_score >=0.0235) or (cc_response_300_score < 0.0121 and cc_response_200_score >=0.0863)) and creative_type in ('185_384_2059')", 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'config': "select * from {0} where ((cc_response_300_score>=0.0121 and cc_response_300_score >=0.0235) or (cc_response_300_score < 0.0121 and cc_response_200_score >=0.0863)) and creative_type in ('185_384_2059')"}], 'desirability_config_id': [2087]}, {'campaign_driver_id': 7944, 'module_config_type_id': 2088, 'module_config_type': 'selection_group_config', 'stage_id': 7, 'sequence_number': 21, 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'description': '$0/$39/$75 Established - $75 AMF Test - RG 3-2 - 620-680 - PS - APR 35% - TM>3 - 1% Reward - Up to $1000', 'credit_policy': '', 'product_cd': 'cc', 'inquiry_code': 'F2E8W005', 'selection_group_type': 'desirability', 'parent_selection_group_config_id': ['480'], 'eligibility_config': [{'selection_group_rule_config_id': 1815, 'selection_group_config_id': 480, 'sequence_number': 1, 'selection_criteria_type': 'eligibility', 'rule_type': 'select', 'rule_condition': '>=', 'description': 'card global response cut', 'rule_value_type': 'decimal', 'attribute_name': 'cc_response_200_score', 'attribute_id': '', 'sql_query': 'cc_response_200_score >= 0.0', 'rule_value': '0.0', 'created_by': 'avantadmin', 'created_date': '2021-12-07', 'is_active_flag': True, 'config': 'select * from {0} where cc_response_200_score >= 0.0'}], 'desirability_config': [{'selection_group_rule_config_id': 4971, 'selection_group_config_id': 2088, 'sequence_number': 1, 'selection_criteria_type': 'desirability', 'rule_type': 'custom', 'rule_condition': 'custom', 'description': '$0/$39/$75 Established - $75 AMF Test - RG 3-2 - 620-680 - PS - APR 35% - TM>3 - 1% Reward - Up to $1000', 'rule_value_type': 'custom', 'attribute_name': 'cc_response_200_score,cc_response_300_score,creative_type', 'attribute_id': '', 'sql_query': "((cc_response_300_score>=0.0121 and cc_response_300_score >=0.0236) or (cc_response_300_score < 0.0121 and cc_response_200_score >=0.0888)) and creative_type in ('185_382_2059')", 'rule_value': "((cc_response_300_score>=0.0121 and cc_response_300_score >=0.0236) or (cc_response_300_score < 0.0121 and cc_response_200_score >=0.0888)) and creative_type in ('185_382_2059')", 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'config': "select * from {0} where ((cc_response_300_score>=0.0121 and cc_response_300_score >=0.0236) or (cc_response_300_score < 0.0121 and cc_response_200_score >=0.0888)) and creative_type in ('185_382_2059')"}], 'desirability_config_id': [2088]}, {'campaign_driver_id': 7945, 'module_config_type_id': 2089, 'module_config_type': 'selection_group_config', 'stage_id': 7, 'sequence_number': 22, 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'description': '$39 Established - ITA - APR 35% - Non-Reward - Up to $1500', 'credit_policy': '', 'product_cd': 'cc', 'inquiry_code': 'F2E8W005', 'selection_group_type': 'desirability', 'parent_selection_group_config_id': ['480'], 'eligibility_config': [{'selection_group_rule_config_id': 1815, 'selection_group_config_id': 480, 'sequence_number': 1, 'selection_criteria_type': 'eligibility', 'rule_type': 'select', 'rule_condition': '>=', 'description': 'card global response cut', 'rule_value_type': 'decimal', 'attribute_name': 'cc_response_200_score', 'attribute_id': '', 'sql_query': 'cc_response_200_score >= 0.0', 'rule_value': '0.0', 'created_by': 'avantadmin', 'created_date': '2021-12-07', 'is_active_flag': True, 'config': 'select * from {0} where cc_response_200_score >= 0.0'}], 'desirability_config': [{'selection_group_rule_config_id': 4972, 'selection_group_config_id': 2089, 'sequence_number': 1, 'selection_criteria_type': 'desirability', 'rule_type': 'custom', 'rule_condition': 'custom', 'description': '$39 Established - ITA - APR 35% - Non-Reward - Up to $1500', 'rule_value_type': 'custom', 'attribute_name': 'cc_response_200_score,cc_response_300_score,creative_type', 'attribute_id': '', 'sql_query': "((cc_response_300_score>=0.0268 and cc_response_300_score >=0.045) or (cc_response_300_score < 0.0268 and cc_response_200_score >=0.0112)) and creative_type in ('185_383_2060')", 'rule_value': "((cc_response_300_score>=0.0268 and cc_response_300_score >=0.045) or (cc_response_300_score < 0.0268 and cc_response_200_score >=0.0112)) and creative_type in ('185_383_2060')", 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'config': "select * from {0} where ((cc_response_300_score>=0.0268 and cc_response_300_score >=0.045) or (cc_response_300_score < 0.0268 and cc_response_200_score >=0.0112)) and creative_type in ('185_383_2060')"}], 'desirability_config_id': [2089]}, {'campaign_driver_id': 7946, 'module_config_type_id': 2090, 'module_config_type': 'selection_group_config', 'stage_id': 7, 'sequence_number': 23, 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'description': '$39 Established - ITA - APR 35% - 1% Reward - Up to $1500', 'credit_policy': '', 'product_cd': 'cc', 'inquiry_code': 'F2E8W005', 'selection_group_type': 'desirability', 'parent_selection_group_config_id': ['480'], 'eligibility_config': [{'selection_group_rule_config_id': 1815, 'selection_group_config_id': 480, 'sequence_number': 1, 'selection_criteria_type': 'eligibility', 'rule_type': 'select', 'rule_condition': '>=', 'description': 'card global response cut', 'rule_value_type': 'decimal', 'attribute_name': 'cc_response_200_score', 'attribute_id': '', 'sql_query': 'cc_response_200_score >= 0.0', 'rule_value': '0.0', 'created_by': 'avantadmin', 'created_date': '2021-12-07', 'is_active_flag': True, 'config': 'select * from {0} where cc_response_200_score >= 0.0'}], 'desirability_config': [{'selection_group_rule_config_id': 4973, 'selection_group_config_id': 2090, 'sequence_number': 1, 'selection_criteria_type': 'desirability', 'rule_type': 'custom', 'rule_condition': 'custom', 'description': '$39 Established - ITA - APR 35% - 1% Reward - Up to $1500', 'rule_value_type': 'custom', 'attribute_name': 'cc_response_200_score,cc_response_300_score,creative_type', 'attribute_id': '', 'sql_query': "((cc_response_300_score>=0.0268 and cc_response_300_score >=0.046) or (cc_response_300_score < 0.0268 and cc_response_200_score >=0.0117)) and creative_type in ('185_384_2060')", 'rule_value': "((cc_response_300_score>=0.0268 and cc_response_300_score >=0.046) or (cc_response_300_score < 0.0268 and cc_response_200_score >=0.0117)) and creative_type in ('185_384_2060')", 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'config': "select * from {0} where ((cc_response_300_score>=0.0268 and cc_response_300_score >=0.046) or (cc_response_300_score < 0.0268 and cc_response_200_score >=0.0117)) and creative_type in ('185_384_2060')"}], 'desirability_config_id': [2090]}, {'campaign_driver_id': 7947, 'module_config_type_id': 2091, 'module_config_type': 'selection_group_config', 'stage_id': 7, 'sequence_number': 24, 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'description': '$39 Established - PS - APR 35% - Non-Reward - Up to $1500', 'credit_policy': '', 'product_cd': 'cc', 'inquiry_code': 'F2E8W005', 'selection_group_type': 'desirability', 'parent_selection_group_config_id': ['480'], 'eligibility_config': [{'selection_group_rule_config_id': 1815, 'selection_group_config_id': 480, 'sequence_number': 1, 'selection_criteria_type': 'eligibility', 'rule_type': 'select', 'rule_condition': '>=', 'description': 'card global response cut', 'rule_value_type': 'decimal', 'attribute_name': 'cc_response_200_score', 'attribute_id': '', 'sql_query': 'cc_response_200_score >= 0.0', 'rule_value': '0.0', 'created_by': 'avantadmin', 'created_date': '2021-12-07', 'is_active_flag': True, 'config': 'select * from {0} where cc_response_200_score >= 0.0'}], 'desirability_config': [{'selection_group_rule_config_id': 4974, 'selection_group_config_id': 2091, 'sequence_number': 1, 'selection_criteria_type': 'desirability', 'rule_type': 'custom', 'rule_condition': 'custom', 'description': '$39 Established - PS - APR 35% - Non-Reward - Up to $1500', 'rule_value_type': 'custom', 'attribute_name': 'cc_response_200_score,cc_response_300_score,creative_type', 'attribute_id': '', 'sql_query': "((cc_response_300_score>=0.0302 and cc_response_300_score >=0.048) or (cc_response_300_score < 0.0302 and cc_response_200_score >=0.0067)) and creative_type in ('185_383_2061')", 'rule_value': "((cc_response_300_score>=0.0302 and cc_response_300_score >=0.048) or (cc_response_300_score < 0.0302 and cc_response_200_score >=0.0067)) and creative_type in ('185_383_2061')", 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'config': "select * from {0} where ((cc_response_300_score>=0.0302 and cc_response_300_score >=0.048) or (cc_response_300_score < 0.0302 and cc_response_200_score >=0.0067)) and creative_type in ('185_383_2061')"}], 'desirability_config_id': [2091]}, {'campaign_driver_id': 7948, 'module_config_type_id': 2092, 'module_config_type': 'selection_group_config', 'stage_id': 7, 'sequence_number': 25, 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'description': '$39 Established - PS - APR 35% - 1% Reward - Up to $1500', 'credit_policy': '', 'product_cd': 'cc', 'inquiry_code': 'F2E8W005', 'selection_group_type': 'desirability', 'parent_selection_group_config_id': ['480'], 'eligibility_config': [{'selection_group_rule_config_id': 1815, 'selection_group_config_id': 480, 'sequence_number': 1, 'selection_criteria_type': 'eligibility', 'rule_type': 'select', 'rule_condition': '>=', 'description': 'card global response cut', 'rule_value_type': 'decimal', 'attribute_name': 'cc_response_200_score', 'attribute_id': '', 'sql_query': 'cc_response_200_score >= 0.0', 'rule_value': '0.0', 'created_by': 'avantadmin', 'created_date': '2021-12-07', 'is_active_flag': True, 'config': 'select * from {0} where cc_response_200_score >= 0.0'}], 'desirability_config': [{'selection_group_rule_config_id': 4975, 'selection_group_config_id': 2092, 'sequence_number': 1, 'selection_criteria_type': 'desirability', 'rule_type': 'custom', 'rule_condition': 'custom', 'description': '$39 Established - PS - APR 35% - 1% Reward - Up to $1500', 'rule_value_type': 'custom', 'attribute_name': 'cc_response_200_score,cc_response_300_score,creative_type', 'attribute_id': '', 'sql_query': "((cc_response_300_score>=0.0302 and cc_response_300_score >=0.0477) or (cc_response_300_score < 0.0302 and cc_response_200_score >=0.0066)) and creative_type in ('185_384_2061')", 'rule_value': "((cc_response_300_score>=0.0302 and cc_response_300_score >=0.0477) or (cc_response_300_score < 0.0302 and cc_response_200_score >=0.0066)) and creative_type in ('185_384_2061')", 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'config': "select * from {0} where ((cc_response_300_score>=0.0302 and cc_response_300_score >=0.0477) or (cc_response_300_score < 0.0302 and cc_response_200_score >=0.0066)) and creative_type in ('185_384_2061')"}], 'desirability_config_id': [2092]}, {'campaign_driver_id': 7949, 'module_config_type_id': 2093, 'module_config_type': 'selection_group_config', 'stage_id': 7, 'sequence_number': 26, 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'description': '$75 Established - From $59 ITA Established - PS - APR 35% - 1% Reward - Up to $1000', 'credit_policy': '', 'product_cd': 'cc', 'inquiry_code': 'F2E8W005', 'selection_group_type': 'desirability', 'parent_selection_group_config_id': ['480'], 'eligibility_config': [{'selection_group_rule_config_id': 1815, 'selection_group_config_id': 480, 'sequence_number': 1, 'selection_criteria_type': 'eligibility', 'rule_type': 'select', 'rule_condition': '>=', 'description': 'card global response cut', 'rule_value_type': 'decimal', 'attribute_name': 'cc_response_200_score', 'attribute_id': '', 'sql_query': 'cc_response_200_score >= 0.0', 'rule_value': '0.0', 'created_by': 'avantadmin', 'created_date': '2021-12-07', 'is_active_flag': True, 'config': 'select * from {0} where cc_response_200_score >= 0.0'}], 'desirability_config': [{'selection_group_rule_config_id': 4976, 'selection_group_config_id': 2093, 'sequence_number': 1, 'selection_criteria_type': 'desirability', 'rule_type': 'custom', 'rule_condition': 'custom', 'description': '$75 Established - From $59 ITA Established - PS - APR 35% - 1% Reward - Up to $1000', 'rule_value_type': 'custom', 'attribute_name': 'cc_response_200_score,cc_response_300_score,creative_type', 'attribute_id': '', 'sql_query': "((cc_response_300_score>=0.0171 and cc_response_300_score >=0.0337) or (cc_response_300_score < 0.0171 and cc_response_200_score >=0.0147)) and creative_type in ('185_382_2062')", 'rule_value': "((cc_response_300_score>=0.0171 and cc_response_300_score >=0.0337) or (cc_response_300_score < 0.0171 and cc_response_200_score >=0.0147)) and creative_type in ('185_382_2062')", 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'config': "select * from {0} where ((cc_response_300_score>=0.0171 and cc_response_300_score >=0.0337) or (cc_response_300_score < 0.0171 and cc_response_200_score >=0.0147)) and creative_type in ('185_382_2062')"}], 'desirability_config_id': [2093]}, {'campaign_driver_id': 7950, 'module_config_type_id': 2094, 'module_config_type': 'selection_group_config', 'stage_id': 7, 'sequence_number': 27, 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'description': '$75 Established - From $59 PS Established - PS - APR 35% - 1% Reward - Up to $1000', 'credit_policy': '', 'product_cd': 'cc', 'inquiry_code': 'F2E8W005', 'selection_group_type': 'desirability', 'parent_selection_group_config_id': ['480'], 'eligibility_config': [{'selection_group_rule_config_id': 1815, 'selection_group_config_id': 480, 'sequence_number': 1, 'selection_criteria_type': 'eligibility', 'rule_type': 'select', 'rule_condition': '>=', 'description': 'card global response cut', 'rule_value_type': 'decimal', 'attribute_name': 'cc_response_200_score', 'attribute_id': '', 'sql_query': 'cc_response_200_score >= 0.0', 'rule_value': '0.0', 'created_by': 'avantadmin', 'created_date': '2021-12-07', 'is_active_flag': True, 'config': 'select * from {0} where cc_response_200_score >= 0.0'}], 'desirability_config': [{'selection_group_rule_config_id': 4977, 'selection_group_config_id': 2094, 'sequence_number': 1, 'selection_criteria_type': 'desirability', 'rule_type': 'custom', 'rule_condition': 'custom', 'description': '$75 Established - From $59 PS Established - PS - APR 35% - 1% Reward - Up to $1000', 'rule_value_type': 'custom', 'attribute_name': 'cc_response_200_score,cc_response_300_score,creative_type', 'attribute_id': '', 'sql_query': "((cc_response_300_score>=0.0247 and cc_response_300_score >=0.0416) or (cc_response_300_score < 0.0247 and cc_response_200_score >=0.0111)) and creative_type in ('185_382_2063')", 'rule_value': "((cc_response_300_score>=0.0247 and cc_response_300_score >=0.0416) or (cc_response_300_score < 0.0247 and cc_response_200_score >=0.0111)) and creative_type in ('185_382_2063')", 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'config': "select * from {0} where ((cc_response_300_score>=0.0247 and cc_response_300_score >=0.0416) or (cc_response_300_score < 0.0247 and cc_response_200_score >=0.0111)) and creative_type in ('185_382_2063')"}], 'desirability_config_id': [2094]}, {'campaign_driver_id': 7951, 'module_config_type_id': 2095, 'module_config_type': 'selection_group_config', 'stage_id': 7, 'sequence_number': 28, 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'description': '$75 Established - ITA - APR 35% - TM=0 - 1% Reward - No line display', 'credit_policy': '', 'product_cd': 'cc', 'inquiry_code': 'F2E8W005', 'selection_group_type': 'desirability', 'parent_selection_group_config_id': ['480'], 'eligibility_config': [{'selection_group_rule_config_id': 1815, 'selection_group_config_id': 480, 'sequence_number': 1, 'selection_criteria_type': 'eligibility', 'rule_type': 'select', 'rule_condition': '>=', 'description': 'card global response cut', 'rule_value_type': 'decimal', 'attribute_name': 'cc_response_200_score', 'attribute_id': '', 'sql_query': 'cc_response_200_score >= 0.0', 'rule_value': '0.0', 'created_by': 'avantadmin', 'created_date': '2021-12-07', 'is_active_flag': True, 'config': 'select * from {0} where cc_response_200_score >= 0.0'}], 'desirability_config': [{'selection_group_rule_config_id': 4978, 'selection_group_config_id': 2095, 'sequence_number': 1, 'selection_criteria_type': 'desirability', 'rule_type': 'custom', 'rule_condition': 'custom', 'description': '$75 Established - ITA - APR 35% - TM=0 - 1% Reward - No line display', 'rule_value_type': 'custom', 'attribute_name': 'cc_response_200_score,cc_response_300_score,creative_type', 'attribute_id': '', 'sql_query': "((cc_response_300_score>=0.0299 and cc_response_300_score >=0.0561) or (cc_response_300_score < 0.0299 and cc_response_200_score >=0.1872)) and creative_type in ('185_393_2064')", 'rule_value': "((cc_response_300_score>=0.0299 and cc_response_300_score >=0.0561) or (cc_response_300_score < 0.0299 and cc_response_200_score >=0.1872)) and creative_type in ('185_393_2064')", 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'config': "select * from {0} where ((cc_response_300_score>=0.0299 and cc_response_300_score >=0.0561) or (cc_response_300_score < 0.0299 and cc_response_200_score >=0.1872)) and creative_type in ('185_393_2064')"}], 'desirability_config_id': [2095]}, {'campaign_driver_id': 7952, 'module_config_type_id': 2096, 'module_config_type': 'selection_group_config', 'stage_id': 7, 'sequence_number': 29, 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'description': '$75 Established - ITA - APR 35% - TM 1-3 - 1% Reward - No line display', 'credit_policy': '', 'product_cd': 'cc', 'inquiry_code': 'F2E8W005', 'selection_group_type': 'desirability', 'parent_selection_group_config_id': ['480'], 'eligibility_config': [{'selection_group_rule_config_id': 1815, 'selection_group_config_id': 480, 'sequence_number': 1, 'selection_criteria_type': 'eligibility', 'rule_type': 'select', 'rule_condition': '>=', 'description': 'card global response cut', 'rule_value_type': 'decimal', 'attribute_name': 'cc_response_200_score', 'attribute_id': '', 'sql_query': 'cc_response_200_score >= 0.0', 'rule_value': '0.0', 'created_by': 'avantadmin', 'created_date': '2021-12-07', 'is_active_flag': True, 'config': 'select * from {0} where cc_response_200_score >= 0.0'}], 'desirability_config': [{'selection_group_rule_config_id': 4979, 'selection_group_config_id': 2096, 'sequence_number': 1, 'selection_criteria_type': 'desirability', 'rule_type': 'custom', 'rule_condition': 'custom', 'description': '$75 Established - ITA - APR 35% - TM 1-3 - 1% Reward - No line display', 'rule_value_type': 'custom', 'attribute_name': 'cc_response_200_score,cc_response_300_score,creative_type', 'attribute_id': '', 'sql_query': "((cc_response_300_score>=0.0305 and cc_response_300_score >=0.0536) or (cc_response_300_score < 0.0305 and cc_response_200_score >=0)) and creative_type in ('185_393_2065')", 'rule_value': "((cc_response_300_score>=0.0305 and cc_response_300_score >=0.0536) or (cc_response_300_score < 0.0305 and cc_response_200_score >=0)) and creative_type in ('185_393_2065')", 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'config': "select * from {0} where ((cc_response_300_score>=0.0305 and cc_response_300_score >=0.0536) or (cc_response_300_score < 0.0305 and cc_response_200_score >=0)) and creative_type in ('185_393_2065')"}], 'desirability_config_id': [2096]}, {'campaign_driver_id': 7953, 'module_config_type_id': 2097, 'module_config_type': 'selection_group_config', 'stage_id': 7, 'sequence_number': 30, 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'description': '$75 Established - PS - APR 35% - 1% Reward - Up to $1000', 'credit_policy': '', 'product_cd': 'cc', 'inquiry_code': 'F2E8W005', 'selection_group_type': 'desirability', 'parent_selection_group_config_id': ['480'], 'eligibility_config': [{'selection_group_rule_config_id': 1815, 'selection_group_config_id': 480, 'sequence_number': 1, 'selection_criteria_type': 'eligibility', 'rule_type': 'select', 'rule_condition': '>=', 'description': 'card global response cut', 'rule_value_type': 'decimal', 'attribute_name': 'cc_response_200_score', 'attribute_id': '', 'sql_query': 'cc_response_200_score >= 0.0', 'rule_value': '0.0', 'created_by': 'avantadmin', 'created_date': '2021-12-07', 'is_active_flag': True, 'config': 'select * from {0} where cc_response_200_score >= 0.0'}], 'desirability_config': [{'selection_group_rule_config_id': 4980, 'selection_group_config_id': 2097, 'sequence_number': 1, 'selection_criteria_type': 'desirability', 'rule_type': 'custom', 'rule_condition': 'custom', 'description': '$75 Established - PS - APR 35% - 1% Reward - Up to $1000', 'rule_value_type': 'custom', 'attribute_name': 'cc_response_200_score,cc_response_300_score,creative_type', 'attribute_id': '', 'sql_query': "((cc_response_300_score>=0.0222 and cc_response_300_score >=0.0371) or (cc_response_300_score < 0.0222 and cc_response_200_score >=0.0899)) and creative_type in ('185_382_2066')", 'rule_value': "((cc_response_300_score>=0.0222 and cc_response_300_score >=0.0371) or (cc_response_300_score < 0.0222 and cc_response_200_score >=0.0899)) and creative_type in ('185_382_2066')", 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'config': "select * from {0} where ((cc_response_300_score>=0.0222 and cc_response_300_score >=0.0371) or (cc_response_300_score < 0.0222 and cc_response_200_score >=0.0899)) and creative_type in ('185_382_2066')"}], 'desirability_config_id': [2097]}], 'transformation_config': [{'campaign_driver_id': 7954, 'campaign_type_config_id': 3, 'module_config_type_id': 1814, 'module_config_type': 'transformation_config', 'stage_id': 7, 'sequence_number': 31, 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'config': {'transformation_config_id': 1814, 'selection_group_config_id': 2069, 'query': '', 'table_location': '', 'properties': {'priority': 1, 'properties': [{'priority': 1, 'creative_code': '185R1_408_2068', 'max_population': 'None', 'allocation_percentage': 100}], 'property_type': 'percentage_split', 'allocation_percentage': 'None'}, 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'description': ''}, 'selection_group_type': 'desirability'}, {'campaign_driver_id': 7955, 'campaign_type_config_id': 3, 'module_config_type_id': 1815, 'module_config_type': 'transformation_config', 'stage_id': 7, 'sequence_number': 32, 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'config': {'transformation_config_id': 1815, 'selection_group_config_id': 2070, 'query': '', 'table_location': '', 'properties': {'priority': 2, 'properties': [{'priority': 2, 'creative_code': '185R1_407_2069', 'max_population': 'None', 'allocation_percentage': 100}], 'property_type': 'percentage_split', 'allocation_percentage': 'None'}, 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'description': ''}, 'selection_group_type': 'desirability'}, {'campaign_driver_id': 7956, 'campaign_type_config_id': 3, 'module_config_type_id': 1816, 'module_config_type': 'transformation_config', 'stage_id': 7, 'sequence_number': 33, 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'config': {'transformation_config_id': 1816, 'selection_group_config_id': 2071, 'query': '', 'table_location': '', 'properties': {'priority': 3, 'properties': [{'priority': 3, 'creative_code': '185R1_409_2070', 'max_population': 'None', 'allocation_percentage': 100}], 'property_type': 'percentage_split', 'allocation_percentage': 'None'}, 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'description': ''}, 'selection_group_type': 'desirability'}, {'campaign_driver_id': 7957, 'campaign_type_config_id': 3, 'module_config_type_id': 1817, 'module_config_type': 'transformation_config', 'stage_id': 7, 'sequence_number': 34, 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'config': {'transformation_config_id': 1817, 'selection_group_config_id': 2072, 'query': '', 'table_location': '', 'properties': {'priority': 4, 'properties': [{'priority': 4, 'creative_code': '185R1_408_2071', 'max_population': 'None', 'allocation_percentage': 100}], 'property_type': 'percentage_split', 'allocation_percentage': 'None'}, 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'description': ''}, 'selection_group_type': 'desirability'}, {'campaign_driver_id': 7958, 'campaign_type_config_id': 3, 'module_config_type_id': 1818, 'module_config_type': 'transformation_config', 'stage_id': 7, 'sequence_number': 35, 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'config': {'transformation_config_id': 1818, 'selection_group_config_id': 2073, 'query': '', 'table_location': '', 'properties': {'priority': 5, 'properties': [{'priority': 5, 'creative_code': '185R1_407_2072', 'max_population': 'None', 'allocation_percentage': 100}], 'property_type': 'percentage_split', 'allocation_percentage': 'None'}, 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'description': ''}, 'selection_group_type': 'desirability'}, {'campaign_driver_id': 7959, 'campaign_type_config_id': 3, 'module_config_type_id': 1819, 'module_config_type': 'transformation_config', 'stage_id': 7, 'sequence_number': 36, 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'config': {'transformation_config_id': 1819, 'selection_group_config_id': 2074, 'query': '', 'table_location': '', 'properties': {'priority': 6, 'properties': [{'priority': 6, 'creative_code': '185R1_406_2073', 'max_population': 'None', 'allocation_percentage': 100}], 'property_type': 'percentage_split', 'allocation_percentage': 'None'}, 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'description': ''}, 'selection_group_type': 'desirability'}, {'campaign_driver_id': 7960, 'campaign_type_config_id': 3, 'module_config_type_id': 1820, 'module_config_type': 'transformation_config', 'stage_id': 7, 'sequence_number': 37, 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'config': {'transformation_config_id': 1820, 'selection_group_config_id': 2075, 'query': '', 'table_location': '', 'properties': {'priority': 7, 'properties': [{'priority': 7, 'creative_code': '185R1_408_2074', 'max_population': 'None', 'allocation_percentage': 100}], 'property_type': 'percentage_split', 'allocation_percentage': 'None'}, 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'description': ''}, 'selection_group_type': 'desirability'}, {'campaign_driver_id': 7961, 'campaign_type_config_id': 3, 'module_config_type_id': 1821, 'module_config_type': 'transformation_config', 'stage_id': 7, 'sequence_number': 38, 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'config': {'transformation_config_id': 1821, 'selection_group_config_id': 2076, 'query': '', 'table_location': '', 'properties': {'priority': 8, 'properties': [{'priority': 8, 'creative_code': '185R1_408_2075', 'max_population': 'None', 'allocation_percentage': 100}], 'property_type': 'percentage_split', 'allocation_percentage': 'None'}, 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'description': ''}, 'selection_group_type': 'desirability'}, {'campaign_driver_id': 7962, 'campaign_type_config_id': 3, 'module_config_type_id': 1822, 'module_config_type': 'transformation_config', 'stage_id': 7, 'sequence_number': 39, 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'config': {'transformation_config_id': 1822, 'selection_group_config_id': 2077, 'query': '', 'table_location': '', 'properties': {'priority': 9, 'properties': [{'priority': 9, 'creative_code': '185R1_408_2076', 'max_population': 'None', 'allocation_percentage': 100}], 'property_type': 'percentage_split', 'allocation_percentage': 'None'}, 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'description': ''}, 'selection_group_type': 'desirability'}, {'campaign_driver_id': 7963, 'campaign_type_config_id': 3, 'module_config_type_id': 1823, 'module_config_type': 'transformation_config', 'stage_id': 7, 'sequence_number': 40, 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'config': {'transformation_config_id': 1823, 'selection_group_config_id': 2078, 'query': '', 'table_location': '', 'properties': {'priority': 10, 'properties': [{'priority': 10, 'creative_code': '185R1_411_2077', 'max_population': 'None', 'allocation_percentage': 100}], 'property_type': 'percentage_split', 'allocation_percentage': 'None'}, 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'description': ''}, 'selection_group_type': 'desirability'}, {'campaign_driver_id': 7964, 'campaign_type_config_id': 3, 'module_config_type_id': 1824, 'module_config_type': 'transformation_config', 'stage_id': 7, 'sequence_number': 41, 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'config': {'transformation_config_id': 1824, 'selection_group_config_id': 2079, 'query': '', 'table_location': '', 'properties': {'priority': 11, 'properties': [{'priority': 11, 'creative_code': '185R1_410_2078', 'max_population': 'None', 'allocation_percentage': 100}], 'property_type': 'percentage_split', 'allocation_percentage': 'None'}, 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'description': ''}, 'selection_group_type': 'desirability'}, {'campaign_driver_id': 7965, 'campaign_type_config_id': 3, 'module_config_type_id': 1825, 'module_config_type': 'transformation_config', 'stage_id': 7, 'sequence_number': 42, 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'config': {'transformation_config_id': 1825, 'selection_group_config_id': 2080, 'query': '', 'table_location': '', 'properties': {'priority': 12, 'properties': [{'priority': 12, 'creative_code': '185R1_408_2079', 'max_population': 'None', 'allocation_percentage': 100}], 'property_type': 'percentage_split', 'allocation_percentage': 'None'}, 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'description': ''}, 'selection_group_type': 'desirability'}, {'campaign_driver_id': 7966, 'campaign_type_config_id': 3, 'module_config_type_id': 1826, 'module_config_type': 'transformation_config', 'stage_id': 7, 'sequence_number': 43, 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'config': {'transformation_config_id': 1826, 'selection_group_config_id': 2081, 'query': '', 'table_location': '', 'properties': {'priority': 13, 'properties': [{'priority': 13, 'creative_code': '185R1_411_2080', 'max_population': 'None', 'allocation_percentage': 100}], 'property_type': 'percentage_split', 'allocation_percentage': 'None'}, 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'description': ''}, 'selection_group_type': 'desirability'}, {'campaign_driver_id': 7967, 'campaign_type_config_id': 3, 'module_config_type_id': 1827, 'module_config_type': 'transformation_config', 'stage_id': 7, 'sequence_number': 44, 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'config': {'transformation_config_id': 1827, 'selection_group_config_id': 2082, 'query': '', 'table_location': '', 'properties': {'priority': 14, 'properties': [{'priority': 14, 'creative_code': '185R1_410_2081', 'max_population': 'None', 'allocation_percentage': 100}], 'property_type': 'percentage_split', 'allocation_percentage': 'None'}, 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'description': ''}, 'selection_group_type': 'desirability'}, {'campaign_driver_id': 7968, 'campaign_type_config_id': 3, 'module_config_type_id': 1828, 'module_config_type': 'transformation_config', 'stage_id': 7, 'sequence_number': 45, 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'config': {'transformation_config_id': 1828, 'selection_group_config_id': 2083, 'query': '', 'table_location': '', 'properties': {'priority': 15, 'properties': [{'priority': 15, 'creative_code': '185R1_408_2082', 'max_population': 'None', 'allocation_percentage': 100}], 'property_type': 'percentage_split', 'allocation_percentage': 'None'}, 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'description': ''}, 'selection_group_type': 'desirability'}, {'campaign_driver_id': 7969, 'campaign_type_config_id': 3, 'module_config_type_id': 1829, 'module_config_type': 'transformation_config', 'stage_id': 7, 'sequence_number': 46, 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'config': {'transformation_config_id': 1829, 'selection_group_config_id': 2084, 'query': '', 'table_location': '', 'properties': {'priority': 16, 'properties': [{'priority': 16, 'creative_code': '185R1_411_2083', 'max_population': 'None', 'allocation_percentage': 100}], 'property_type': 'percentage_split', 'allocation_percentage': 'None'}, 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'description': ''}, 'selection_group_type': 'desirability'}, {'campaign_driver_id': 7970, 'campaign_type_config_id': 3, 'module_config_type_id': 1830, 'module_config_type': 'transformation_config', 'stage_id': 7, 'sequence_number': 47, 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'config': {'transformation_config_id': 1830, 'selection_group_config_id': 2085, 'query': '', 'table_location': '', 'properties': {'priority': 17, 'properties': [{'priority': 17, 'creative_code': '185R1_410_2084', 'max_population': 'None', 'allocation_percentage': 100}], 'property_type': 'percentage_split', 'allocation_percentage': 'None'}, 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'description': ''}, 'selection_group_type': 'desirability'}, {'campaign_driver_id': 7971, 'campaign_type_config_id': 3, 'module_config_type_id': 1831, 'module_config_type': 'transformation_config', 'stage_id': 7, 'sequence_number': 48, 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'config': {'transformation_config_id': 1831, 'selection_group_config_id': 2086, 'query': '', 'table_location': '', 'properties': {'priority': 18, 'properties': [{'priority': 18, 'creative_code': '185R1_408_2085', 'max_population': 'None', 'allocation_percentage': 100}], 'property_type': 'percentage_split', 'allocation_percentage': 'None'}, 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'description': ''}, 'selection_group_type': 'desirability'}, {'campaign_driver_id': 7972, 'campaign_type_config_id': 3, 'module_config_type_id': 1832, 'module_config_type': 'transformation_config', 'stage_id': 7, 'sequence_number': 49, 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'config': {'transformation_config_id': 1832, 'selection_group_config_id': 2087, 'query': '', 'table_location': '', 'properties': {'priority': 19, 'properties': [{'priority': 19, 'creative_code': '185R1_411_2086', 'max_population': 'None', 'allocation_percentage': 100}], 'property_type': 'percentage_split', 'allocation_percentage': 'None'}, 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'description': ''}, 'selection_group_type': 'desirability'}, {'campaign_driver_id': 7973, 'campaign_type_config_id': 3, 'module_config_type_id': 1833, 'module_config_type': 'transformation_config', 'stage_id': 7, 'sequence_number': 50, 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'config': {'transformation_config_id': 1833, 'selection_group_config_id': 2088, 'query': '', 'table_location': '', 'properties': {'priority': 20, 'properties': [{'priority': 20, 'creative_code': '185R1_410_2087', 'max_population': 'None', 'allocation_percentage': 100}], 'property_type': 'percentage_split', 'allocation_percentage': 'None'}, 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'description': ''}, 'selection_group_type': 'desirability'}, {'campaign_driver_id': 7974, 'campaign_type_config_id': 3, 'module_config_type_id': 1834, 'module_config_type': 'transformation_config', 'stage_id': 7, 'sequence_number': 51, 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'config': {'transformation_config_id': 1834, 'selection_group_config_id': 2089, 'query': '', 'table_location': '', 'properties': {'priority': 21, 'properties': [{'priority': 21, 'creative_code': '185R1_413_2088', 'max_population': 'None', 'allocation_percentage': 100}], 'property_type': 'percentage_split', 'allocation_percentage': 'None'}, 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'description': ''}, 'selection_group_type': 'desirability'}, {'campaign_driver_id': 7975, 'campaign_type_config_id': 3, 'module_config_type_id': 1835, 'module_config_type': 'transformation_config', 'stage_id': 7, 'sequence_number': 52, 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'config': {'transformation_config_id': 1835, 'selection_group_config_id': 2090, 'query': '', 'table_location': '', 'properties': {'priority': 22, 'properties': [{'priority': 22, 'creative_code': '185R1_411_2089', 'max_population': 'None', 'allocation_percentage': 100}], 'property_type': 'percentage_split', 'allocation_percentage': 'None'}, 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'description': ''}, 'selection_group_type': 'desirability'}, {'campaign_driver_id': 7976, 'campaign_type_config_id': 3, 'module_config_type_id': 1836, 'module_config_type': 'transformation_config', 'stage_id': 7, 'sequence_number': 53, 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'config': {'transformation_config_id': 1836, 'selection_group_config_id': 2091, 'query': '', 'table_location': '', 'properties': {'priority': 23, 'properties': [{'priority': 23, 'creative_code': '185R1_413_2090', 'max_population': 'None', 'allocation_percentage': 100}], 'property_type': 'percentage_split', 'allocation_percentage': 'None'}, 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'description': ''}, 'selection_group_type': 'desirability'}, {'campaign_driver_id': 7977, 'campaign_type_config_id': 3, 'module_config_type_id': 1837, 'module_config_type': 'transformation_config', 'stage_id': 7, 'sequence_number': 54, 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'config': {'transformation_config_id': 1837, 'selection_group_config_id': 2092, 'query': '', 'table_location': '', 'properties': {'priority': 24, 'properties': [{'priority': 24, 'creative_code': '185R1_411_2091', 'max_population': 'None', 'allocation_percentage': 100}], 'property_type': 'percentage_split', 'allocation_percentage': 'None'}, 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'description': ''}, 'selection_group_type': 'desirability'}, {'campaign_driver_id': 7978, 'campaign_type_config_id': 3, 'module_config_type_id': 1838, 'module_config_type': 'transformation_config', 'stage_id': 7, 'sequence_number': 55, 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'config': {'transformation_config_id': 1838, 'selection_group_config_id': 2093, 'query': '', 'table_location': '', 'properties': {'priority': 25, 'properties': [{'priority': 25, 'creative_code': '185R1_410_2092', 'max_population': 'None', 'allocation_percentage': 100}], 'property_type': 'percentage_split', 'allocation_percentage': 'None'}, 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'description': ''}, 'selection_group_type': 'desirability'}, {'campaign_driver_id': 7979, 'campaign_type_config_id': 3, 'module_config_type_id': 1839, 'module_config_type': 'transformation_config', 'stage_id': 7, 'sequence_number': 56, 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'config': {'transformation_config_id': 1839, 'selection_group_config_id': 2094, 'query': '', 'table_location': '', 'properties': {'priority': 26, 'properties': [{'priority': 26, 'creative_code': '185R1_410_2093', 'max_population': 'None', 'allocation_percentage': 100}], 'property_type': 'percentage_split', 'allocation_percentage': 'None'}, 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'description': ''}, 'selection_group_type': 'desirability'}, {'campaign_driver_id': 7980, 'campaign_type_config_id': 3, 'module_config_type_id': 1840, 'module_config_type': 'transformation_config', 'stage_id': 7, 'sequence_number': 57, 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'config': {'transformation_config_id': 1840, 'selection_group_config_id': 2095, 'query': '', 'table_location': '', 'properties': {'priority': 27, 'properties': [{'priority': 27, 'creative_code': '185R1_412_2094', 'max_population': 'None', 'allocation_percentage': 100}], 'property_type': 'percentage_split', 'allocation_percentage': 'None'}, 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'description': ''}, 'selection_group_type': 'desirability'}, {'campaign_driver_id': 7981, 'campaign_type_config_id': 3, 'module_config_type_id': 1841, 'module_config_type': 'transformation_config', 'stage_id': 7, 'sequence_number': 58, 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'config': {'transformation_config_id': 1841, 'selection_group_config_id': 2096, 'query': '', 'table_location': '', 'properties': {'priority': 28, 'properties': [{'priority': 28, 'creative_code': '185R1_412_2095', 'max_population': 'None', 'allocation_percentage': 100}], 'property_type': 'percentage_split', 'allocation_percentage': 'None'}, 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'description': ''}, 'selection_group_type': 'desirability'}, {'campaign_driver_id': 7982, 'campaign_type_config_id': 3, 'module_config_type_id': 1842, 'module_config_type': 'transformation_config', 'stage_id': 7, 'sequence_number': 59, 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'config': {'transformation_config_id': 1842, 'selection_group_config_id': 2097, 'query': '', 'table_location': '', 'properties': {'priority': 29, 'properties': [{'priority': 29, 'creative_code': '185R1_410_2096', 'max_population': 'None', 'allocation_percentage': 100}], 'property_type': 'percentage_split', 'allocation_percentage': 'None'}, 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'description': ''}, 'selection_group_type': 'desirability'}], 'approval_config': [{'campaign_driver_id': 7983, 'module_config_type_id': 3, 'module_config_type': 'approval_config', 'stage_id': 7, 'sequence_number': 60, 'created_by': 'avantadmin', 'created_date': '2021-06-23', 'is_active_flag': True, 'config': {'approval_config_id': 3, 'email_address': '\tcampaign-dev@avant.com', 'role': 'pipeline_alert', 'alert_type': 'notification', 'created_by': 'avantadmin', 'created_date': '2021-06-23', 'is_active_flag': True, 'description': ''}}, {'campaign_driver_id': 7984, 'module_config_type_id': 68, 'module_config_type': 'approval_config', 'stage_id': 7, 'sequence_number': 61, 'created_by': 'avantadmin', 'created_date': '2023-02-27', 'is_active_flag': True, 'config': {'approval_config_id': 68, 'email_address': 'diana.guan@avant.com,patrick.colucci@avant.com,yixue.lu@avant.com,ashay.gupta@avant.com,malika.tarabichi@avant.com,henan.ma@avant.com,brad.nelsen@avant.com', 'role': 'data_approval', 'alert_type': 'notification', 'created_by': 'avantadmin', 'created_date': '2023-02-27', 'is_active_flag': True, 'description': "Direct Mail approvers' email list - April 2023"}}]}, '8': {'transformation_config': [{'campaign_driver_id': 7985, 'campaign_type_config_id': 3, 'module_config_type_id': 7, 'module_config_type': 'transformation_config', 'stage_id': 8, 'sequence_number': 1, 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'config': {'transformation_config_id': 7, 'selection_group_config_id': None, 'query': 'select contact_urn, perm_id, tu_perm_id, indiv_id, hh_id, first_name, middle_name, last_name, address, unit_type, unit_number, city_name, state, poc, zip_code, zip4_code, bpid, consumerid, sequencenumber, send_id, remail_creative_code as creative_cd, campaign_name,  pl_response_400_score as marketing_Score, ssn8 from {}', 'table_location': '', 'properties': None, 'created_by': 'avantadmin', 'created_date': '2021-07-19', 'is_active_flag': True, 'description': 'avantadmin'}, 'selection_group_type': 'NULL'}], 'publish_config': [{'campaign_driver_id': 7986, 'module_config_type_id': 4, 'module_config_type': 'publish_config', 'stage_id': 8, 'sequence_number': 2, 'created_by': 'avantadmin', 'created_date': '2020-12-03', 'is_active_flag': True, 'config': {'publish_config_id': 4, 'publish_type': 'S3', 'publish_path': 'avant-partner01-landing', 'secret_path': 'app/landing_zone_encryption/non-prod', 'file_format_type': 'csv', 'encrypt': '1', 'created_by': 'avantadmin', 'created_date': '2020-12-03', 'is_active_flag': True, 'description': 'Remail Acxiom Publish'}}]}, '9': {'ingestion_config': [{'campaign_driver_id': 7987, 'module_config_type_id': 5, 'module_config_type': 'ingestion_config', 'stage_id': 9, 'sequence_number': 1, 'created_by': 'avantadmin', 'created_date': '2020-12-03', 'is_active_flag': True, 'config': {'ingestion_config_id': 5, 'source_type': 's3', 'source_partner': '', 'secret_path': 'app/landing_zone_encryption/acxiom/2024', 'source_key_type': '', 'source_name': 'avant-partner01-landing', 'source_key': 'acxiom/drop/mailed/AVANT_REMAIL_MAILED_PII_', 'source_key_pattern': '', 'is_encrypted': '1', 'created_by': 'avantadmin', 'created_date': '2020-12-03', 'is_active_flag': True, 'target_type': 's3', 'target_location': 'avantcamp-partner01-{}-transient-bucket', 'description': 'Remail Mailed'}}], 'transformation_config': [{'campaign_driver_id': 7988, 'campaign_type_config_id': 3, 'module_config_type_id': 8, 'module_config_type': 'transformation_config', 'stage_id': 9, 'sequence_number': 2, 'created_by': 'avantadmin', 'created_date': '2024-05-13', 'is_active_flag': True, 'config': {'transformation_config_id': 8, 'selection_group_config_id': None, 'query': "SELECT  \n    remail_poc as promo_code,\n    remail_creative_type as url,\n    perm_id,\n    first_name,\n    middle_name,\n    last_name,\n    address,\n    unit_type,\n    unit_number,\n    city_name as city,\n    state,\n    zip_code as zip,\n    '' as fico_score,\n    ssn8 as ssn_last_8,\n    '' as a_score,\n    '' as b_score,\n    '' as c_score \nFROM {}", 'table_location': '', 'properties': None, 'created_by': 'avantadmin', 'created_date': '2021-07-19', 'is_active_flag': True, 'description': 'avantadmin'}, 'selection_group_type': 'NULL'}], 'publish_config': [{'campaign_driver_id': 7989, 'module_config_type_id': 5, 'module_config_type': 'publish_config', 'stage_id': 9, 'sequence_number': 3, 'created_by': 'avantadmin', 'created_date': '2020-12-03', 'is_active_flag': True, 'config': {'publish_config_id': 5, 'publish_type': 'S3', 'publish_path': 'avant-acxiom', 'secret_path': 'app/landing_zone_encryption/amount_encryption', 'file_format_type': 'csv', 'encrypt': '1', 'created_by': 'avantadmin', 'created_date': '2020-12-03', 'is_active_flag': True, 'description': 'Remail Amount Publish'}}]}}, 'campaign_name': 'remail_may_2024', 'campaign_config_s3_path': 'None', 'campaign_deployment_log_id': 1483, 'name': 'Remail', 'table_name': 'campaign_config.campaign_driver_config', 'campaign_driver_config_id': 35092, 'acxiom_config': {'remail_acxiom': {'header': 'false', 'task_id': ['remail_acxiom'], 'input_path': 'remail_publish', 'repartition': 1, 'publish_transform': 'direct_mail_mailed_transform', 'target_file_prefix': 'remail_acxiom_publish_path', 'publish_source_path': 'remail_deduped_final', 'publish_target_path': 'remail_publish', 'source_target_prefix_dict': {'remail_publish': 'remail_acxiom_publish_file_name'}}, 'remail_amount': {'header': 'true', 'file_id': ['acxiom_004'], 'task_id': ['remail_amount'], 'config_id': [0], 'transform': 'direct_mail_mailed_transform', 'input_path': 'direct_mail_remailed_transformation', 'file_format': 'csv', 'repartition': 1, 'source_path': 'remail_mailed_ingestion', 'target_path': 'remail_transformation', 'infer_schema': 'direct_mail_infer_schema', 'file_processed': ['remail_file_processed'], 'target_file_prefix': 'remail_publish_path'}}}
import sys
import traceback
from campaign_utils.logging_helpers import LoggingHelper
from pyspark.sql.functions import *
from campaign_utils.sql_query import SqlQuery
from campaign_utils.db_helpers import DBHelpers

LoggingHelper.logging_helper(
    component_type='campaign_component',
    db_func_type='update',
    audit_args=args,
    config_args=campaign_config,
    code_state=2
)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# authenticated
# no results to fetch

# %%
data_file_path = args['direct_mail_first_mail_transformation']
direct_mail_selected_path = args['direct_mail_selected_path']
db_obj = DBHelpers(args)
program_path_query = SqlQuery.GET_SEND_ID
send_id = db_obj.execute_query(program_path_query)[0][0]
args['send_id'] = str(send_id) + 'R1'
id_column_name = 'bpid'
mailed_df = spark.read.load(data_file_path, format='parquet')
selected_df = spark.read.load(direct_mail_selected_path, format='parquet')
select_columns_list = ['bpid',
                       'times_mailed_card_last_9_sends',
                       'credit_card_20_score', 'income_300_score', 'cc_short_term_110_score', 'pl_short_term_100_score',
                       'pl_response_400_score', 'pl_default_520_score', 'income_101_score', 'bankruptcy_200_score',
                       'default_510_xgb_score', 'default_510_little_recent_score', 'default_510_lots_recent_score',
                       'credit_card_11_score', 'cc_response_100_score', 'cc_response_200_score','cc_response_300_score', 'cc_default_30_score',
                       'adj_pl_default_520_score']

selected_df = selected_df.select(*select_columns_list)

mailed_df_col = mailed_df.columns
selected_df_col = selected_df.columns

duplicate_cols = [
    i
    for i in mailed_df_col
    if i in selected_df_col and i != id_column_name
]

if len(duplicate_cols) > 0:
    selected_df = selected_df.drop(*duplicate_cols)

final_df = mailed_df.join(
    selected_df,
    id_column_name,
    how='left'
)

final_df = final_df.withColumn(
    "campaign_name", lit(args['campaign_run_name'])).withColumn(
    "send_id", lit(args['send_id']))
final_df = final_df.withColumnRenamed(
    "external_model_2_score", "fico_score")

#     final_df.write.mode('overwrite').parquet(args['acxiom_joined_with_scoring_file_ingestion'])

#     LoggingHelper.logging_helper(
#         component_type='campaign_component',
#         db_func_type='update',
#         audit_args=args,
#         config_args=campaign_config,
#         code_state=3
#     )

# except Exception:
#     exc_type, exc_value, exc_traceback = sys.exc_info()
#     error_message = " ".join(
#         traceback.format_exception(
#             exc_type,
#             exc_value,
#             exc_traceback
#         )
#     ).strip('\n')
#     LoggingHelper.logging_helper(
#         component_type='campaign_component',
#         db_func_type='update',
#         audit_args=args,
#         config_args=campaign_config,
#         code_state='failed',
#         message=error_message
#     )
#     raise
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# authenticated

# %%
final_df.write.mode('overwrite').parquet(args['acxiom_joined_with_scoring_file_ingestion'])
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
