 'vault_encrypt_path': 'app/landing_zone_encryption/amount/prod', 'secret_path': 'app/abc/dev', 'DREMIO_USERNAME': 'XXXXXXXXXX', 'DREMIO_PASSWORD': 'XXXXXXXXXX', 'ec2_role': 'airflow-role', 'role_name': 'avant-dlds-airflow-dev-ecs-task-role', 'emr_role_name': 'ec2_run_terraform', 'metadata_url_base': 'http://169.254.169.254', 'VAULT_URL': 'https://vault.shared.partner01.data.avant.com', 'source_file_creation_time': '2023-02-24 15:00:15', 'file_list': ['responsys/drop/6987_PUSH_SKIPPED_20230224_030005.txt.zip', 'responsys/drop/6987_PUSH_SKIPPED_20230224_150003.txt.zip'], 'current_year': '2023', 'current_month': '02', 'current_day': '24', 'current_hour': '16', 'batch_id': '31506', 'run_id': '1', 'key': 'file_id_responsys_017', 'business_date': '1970-01-20', 'file_creation_time': '1970-01-20 09:53:27', 'run_date': '20230224', 'feed_meta': 's3://avantdlds-partner01-dev-common-bucket/common/feed_metadata.cfg', 'cur_date': '2023/02/24', 'feed_attr': 's3://avantdlds-partner01-dev-common-bucket/common/feed_attr.cfg', 'env': 'dev', 'gpg_vault_version': 3, 'attribute_list': [], 'data_type_list': [('EVENT_UUID', 'String'), ('EVENT_TYPE_ID', 'integer'), ('ACCOUNT_ID', 'integer'), ('LIST_ID', 'integer'), ('RIID', 'long'), ('CUSTOMER_ID', 'long'), ('CAMPAIGN_ID', 'long'), ('LAUNCH_ID', 'long'), ('PROGRAM_ID', 'long'), ('PUSH_ID', 'integer'), ('USER_ID', 'integer'), ('APP_ID', 'integer'), ('REASON', 'String'), ('PLATFORM_TYPE', 'String'), ('EVENT_CAPTURED_DT', 'String'), ('EVENT_STORED_DT', 'String')], 'target_data_type_list': [('AC_ID', 'long'), ('ACCOUNT_ID', 'integer'), ('APP_ID', 'integer'), ('BOUNCE_TYPE', 'String'), ('BROWSER', 'String'), ('BROWSER_TYPE', 'String'), ('CAMPAIGN_ID', 'long'), ('CAMPAIGN_NAME', 'String'), ('COMPLAINER_EMAIL', 'String'), ('CONTACT_INFO', 'String'), ('CUSTOMER_ID', 'long'), ('DESCRIPTION', 'String'), ('EMAIL', 'String'), ('EMAIL_FORMAT', 'String'), ('EMAIL_ISP', 'String'), ('EVENT_UUID', 'String'), ('EXTERNAL_CAMPAIGN_ID', 'long'), ('FORM_NAME', 'String'), ('LAUNCH_CHARSET', 'String'), ('LAUNCH_ERROR_CODE', 'String'), ('LAUNCH_NAME', 'String'), ('LAUNCH_STATUS', 'String'), ('LAUNCH_TYPE', 'String'), ('LIST_ID', 'integer'), ('MARKETING_PROGRAM', 'String'), ('MARKETING_STRATEGY', 'String'), ('OFFER_CATEGORY', 'String'), ('OFFER_NAME', 'String'), ('LAUNCH_ID', 'long'), ('DYNAMIC_CONTENT_SIGNATURE_ID', 'integer'), ('ENACTMENT_ID', 'long'), ('EVENT_TYPE_ID', 'integer'), ('FORM_ID', 'long'), ('MESSAGE_SIZE', 'integer'), ('OFFER_NUMBER', 'long'), ('OFFER_SIGNATURE_ID', 'integer'), ('OFFER_URL', 'String'), ('OPERATING_SYSTEM', 'String'), ('ORDER_ID', 'integer'), ('ORDER_QUANTITY', 'integer'), ('ORDER_TOTAL', 'double'), ('PLATFORM_TYPE', 'String'), ('PRODUCT_CATEGORY', 'String'), ('PRODUCT_TYPE', 'String'), ('PROGRAM_DESCRIPTION', 'String'), ('PROGRAM_NAME', 'String'), ('PURPOSE', 'String'), ('PUSH_ID', 'integer'), ('PUSHIO_API_KEY', 'String'), ('REASON', 'String'), ('REASON_CODE', 'String'), ('RIID', 'long'), ('SEGMENT_INFO', 'String'), ('SOURCE', 'String'), ('SPAM_TYPE', 'String'), ('SUBJECT', 'String'), ('USER_AGENT_STRING', 'String'), ('USER_ID', 'integer'), ('PROGRAM_VERSION', 'integer'), ('PROGRAM_ID', 'long'), ('SF_CAMPAIGN_ID', 'long'), ('COMPLAINT_DT', 'String'), ('EMAIL_DATE', 'String'), ('EVENT_CAPTURED_DT', 'String'), ('EVENT_STORED_DT', 'String'), ('LAUNCH_COMPLETED_DT', 'String'), ('LAUNCH_STARTED_DT', 'String')], 'partner_id': 'partner01', 'sub_partner': 'avant', 'dag_name': 'responsys', 'application_sub_name': 'responsys_017', 'job_id': 310217, 'program_name': 'responsys_ingest_to_transient.py', 'DREMIO_SERVER_URL': 'https://dremio-nonprod.services.global.avant.com', 'file_number': '17'}, 'responsys_018': {'feed_attribute_object': 'common/feed_attr.cfg', 'feed_metadata_object': 'common/feed_metadata.cfg', 'uow_dependency_object': 'common/uow_dependency.cfg', 'uow_error_object': 'common/uow_error.cfg', 'verifications_queue_vds_path': 'avant.{}.dw.dw_orig.verifications_queue_session', 'responsys_pds_path': 'avantdlds-partner01-nonprod.avantdlds-partner01-{}-transform-bucket.responsys.responsys_020.dedupe_responsys', 'responsys_012_raw_pds_path': 'avantdlds-partner01-nonprod.avantdlds-partner01-{}-raw-bucket.responsys.responsys_012', 'responsys_data_path': 'responsys/responsys/2023/02/24', 'responsys_012_raw': 'responsys/responsys_012/2023/02/24', 'MasterSecurityGroupName': 'AirflowEMRMasterSG', 'SlaveSecurityGroupName': 'AirflowEMRSlaveSG', 'SubnetKeyName': 'data-partner01-{}-private-app-2a', 'DB_CLUSTER_IDENTIFIER': 'auroraclusteroperational', 'instance_profile_role': 'ec2_run_terraform', 'service_role': 'EC_EMR_DEFAULTBBI', 'auto_scaling_role': 'EC_EMR_DEFAULTBBI', 'EMR_EC_PEM_FILE': 'EC2_BBI_DEV', 'ServiceSecurityGroupName': 'AirflowServiceSecurityGroup', 'common_bucket': 'avantdlds-partner01-dev-common-bucket', 'exception_bucket': 'avantdlds-partner01-dev-exception-bucket', 'log_bucket': 'avantdlds-partner01-dev-log-bucket', 'verifications_stage_vds_path': 'avant.{}.dw.dw_orig.verifications_stage_session', 'aws_read_shared_vpc': 'arn:aws:iam::336913029742:role/admin_access_for_{}_from_shared', 'workflow_file_id': 'workflow_001', 'workflow_application': 'workflow', 'avant_reproc_source_type': 'Reproc', 'loaded_by': 'avantadmin', 'config_file_name': 'common/feed_metadata.cfg', 'parameter_config_file': 'common/parameters.cfg', 'region': 'us-east-2', 'feed_attribute_config_file': 'common/feed_attr.cfg', 'helpscout_batch_conversation_file_id': 'helpscout_001', 'helpscout_batch_threads_file_id': 'helpscout_002', 'mailbox_csv_path': '/common/Mailboxes.csv', 'cluster_id': 'cluster_id', 'spark_application_type': 'pyspark', 'aws_connection_id': 'aws_default', 'ref_data_object': 'common/reference_data.cfg', 'dremio_security_table_name': 'dremio_security', 'OPS_TABLE_S3_BUCKET_TABLE': 'S3_BUCKET_TABLE', 'OPS_TABLE_BATCH_RUN_STATS': 'BATCH_RUN_STATS', 'OPS_TABLE_BATCH_REPORTS': 'BATCH_REPORTS', 'transunion_account_review_file_id': 'transunion_001', 'transunion_account_review_application': 'transunion', 'EMAIL_RESPONSE_SLA_PATH': 'common/Email_Response_SLA.csv', 'landing_prefix_path': 'responsys/drop', 'loan_by_day': 'loan_by_day/loan_by_day_003/dedup_loan_by_day/', 'loan_payment_plan_v3_union': 'account_portfolios_union/account_portfolios_union_001/loan_payment_plan/loan_payment_plan_union', 'dedup_loan_by_day': 'loan_by_day/loan_by_day_003/dedup_loan_by_day', 'loan_financial_owner_v3_union': 'account_portfolios_union/account_portfolios_union_001/loan_financial_owner/loan_financial_owner_union', 'loan_by_day_v3': 'loan_by_day/loan_by_day_003/dedup_loan_by_day/', 'raw_loan_by_day': 'loan_by_day/loan_by_day_003/loan_by_day/*/*/*/*/*/', 'dedup_loan_balance_by_day': 'loan_balance_by_day/loan_balance_by_day_001/loan_balance_by_day/', 'responsys_log_file_path': 'log/responsys/responsys_019/2023/02/24', 'responsys_vds_path': 'avant.{}.dw.dw_orig.responsys', 'first_data_monetary_detail_charge_off_data_lake_dedup_file': 'first_data/first_data_007/dedup_monetary_detail_charge_off', 'first_data_monetary_detail_cross_cycle_adjustment_data_lake_dedup_file': 'first_data/first_data_008/dedup_monetary_detail_cross_cycle_adjustment', 'first_data_monetary_detail_current_cycle_adjustment_data_lake_dedup_file': 'first_data/first_data_009/dedup_monetary_detail_current_cycle_adjustment', 'loan_customer_application_history_l0_vds_path_intermediate': 'avant.{}.intermediate.dw.dw_orig_history.loan_customer_application_history_l0', 'first_data_monetary_detail_transaction_data_lake_dedup_file': 'first_data/first_data_010/dedup_monetary_detail_transaction', 'first_data_fraud_falcon_data_lake_dedup_file': 'first_data/first_data_005/dedup_fraud_falcon', 'raw_bucket': 'avantdlds-partner01-dev-raw-bucket', 'stage_bucket': 'avantdlds-partner01-dev-stage-bucket', 'transform_bucket': 'avantdlds-partner01-dev-transform-bucket', 'transient_bucket': 'avantdlds-partner01-dev-transient-bucket', 'outgoing_bucket': 'avantdlds-partner01-dev-outgoing-bucket', 'first_data_historical_cardholder_data_data_lake_dedup_file': 'first_data/first_data_006/dedup_historical_cardholder_data', 'first_data_account_data_lake_dedup_file': 'first_data/first_data_001/dedup_account', 'first_data_account_delinquency_data_lake_dedup_file': 'first_data/first_data_002/dedup_account_delinquency', 'fd_cc_lv_account_data_lake_dedup_file': 'fd_cc_lv/fd_cc_lv_001/dedup_account', 'fd_cc_lv_account_delinquency_data_lake_dedup_file': 'fd_cc_lv/fd_cc_lv_002/dedup_account_delinquency', 'fd_cc_lv_account_delinquency_items_data_lake_dedup_file': 'fd_cc_lv/fd_cc_lv_003/dedup_account_delinquency_items', 'fd_cc_lv_current_monetary_activity_data_lake_dedup_file': 'fd_cc_lv/fd_cc_lv_004/dedup_current_monetary_activity', 'first_data_account_delinquency_items_data_lake_dedup_file': 'first_data/first_data_003/dedup_account_delinquency_items', 'drop_bucket': 'avant-partner01-landing', 'first_data_current_monetary_activity_data_lake_dedup_file': 'first_data/first_data_004/dedup_current_monetary_activity', 'responsys_001_raw_vds_path': 'avant.{}.dl.responsys.responsys_001', 'key_path': '[0-9]{4}_SKIPPED_[0-9]{8}_[0-9]{6}.txt.zip', 'responsys_002_raw_pds_path': 'avantdlds-partner01-nonprod.avantdlds-partner01-{}-raw-bucket.responsys.responsys_002', 'cust_app_dedup_file': 'customer_application/customer_application_001/dedup_loan_customer_application', 'cust_app_experiment_dedup_file': 'customer_application/customer_application_005/dedup_loan_customer_application_experiment', 'responsys_005_raw_pds_path': 'avantdlds-partner01-nonprod.avantdlds-partner01-{}-raw-bucket.responsys.responsys_005', 'dremio_security_redesign': '"Security".dremio_security_redesign', 'cca_cust_app_dedup_file': 'credit_card_customer_application/credit_card_customer_application_001/dedup_cc_account_customer_application', 'fd_cc_lv_fraud_falcon_data_lake_dedup_file': 'fd_cc_lv/fd_cc_lv_005/dedup_fraud_falcon', 'responsys_010_raw_pds_path': 'avantdlds-partner01-nonprod.avantdlds-partner01-{}-raw-bucket.responsys.responsys_010', 'responsys_stage_log_file_name': 'responsys_019_stage_31510_1_20230224.log', 'responsys_011_raw_pds_path': 'avantdlds-partner01-nonprod.avantdlds-partner01-{}-raw-bucket.responsys.responsys_011', 'responsys_013_raw_pds_path': 'avantdlds-partner01-nonprod.avantdlds-partner01-{}-raw-bucket.responsys.responsys_013', 'responsys_014_raw_pds_path': 'avantdlds-partner01-nonprod.avantdlds-partner01-{}-raw-bucket.responsys.responsys_014', 'responsys_015_raw_pds_path': 'avantdlds-partner01-nonprod.avantdlds-partner01-{}-raw-bucket.responsys.responsys_015', 'responsys_016_raw_pds_path': 'avantdlds-partner01-nonprod.avantdlds-partner01-{}-raw-bucket.responsys.responsys_016', 'responsys_017_raw_pds_path': 'avantdlds-partner01-nonprod.avantdlds-partner01-{}-raw-bucket.responsys.responsys_017', 'partner01_source': 'avantdlds-partner01-nonprod', 'workflow_script_sessions': 'pyspark/workflow/pyspark/workflow_session.py', 'workflow_script_session_types': 'pyspark/workflow/pyspark/workflow_type_session.py', 'workflow_script_validations': 'pyspark/workflow/pyspark/workflow_validation.py', 'workflow_script_step': 'pyspark/workflow/pyspark/workflow_step.py', 'dedup_loan_transcation_v3': 'loan_transaction/loan_transaction_003/dedup_loan_transaction/', 'verification_stage_session_join_data_path': 'verifications/verifications_011/join_verification_stage_session', 'verification_queue_session_join_data_path': 'verifications/verifications_010/join_verification_queue_session', 'avant_source_type': 'Regular', 'responsys_018_raw_pds_path': 'avantdlds-partner01-nonprod.avantdlds-partner01-{}-raw-bucket.responsys.responsys_018', 'responsys_019_raw_pds_path': 'avantdlds-partner01-nonprod.avantdlds-partner01-{}-raw-bucket.responsys.responsys_019', 'fd_cc_lv_historical_cardholder_data_data_lake_dedup_file': 'fd_cc_lv/fd_cc_lv_006/dedup_historical_cardholder_data', 'fd_cc_lv_monetary_detail_charge_off_data_lake_dedup_file': 'fd_cc_lv/fd_cc_lv_007/dedup_monetary_detail_charge_off', 'af_dremio_hostname_nonprod': 'ip-10-240-8-173.us-east-2.compute.internal', 'af_dremio_hostname_prod': 'ip-10-240-6-103.us-east-2.compute.internal', 'responsys_001_raw_pds_path': 'avantdlds-partner01-nonprod.avantdlds-partner01-{}-raw-bucket.responsys.responsys_001', 'responsys_003_raw_pds_path': 'avantdlds-partner01-nonprod.avantdlds-partner01-{}-raw-bucket.responsys.responsys_003', 'responsys_006_raw_vds_path': 'avant.{}.dl.responsys.responsys_006', 'responsys_006_raw_pds_path': 'avantdlds-partner01-nonprod.avantdlds-partner01-{}-raw-bucket.responsys.responsys_006', 'responsys_008_raw_pds_path': 'avantdlds-partner01-nonprod.avantdlds-partner01-{}-raw-bucket.responsys.responsys_008', 'ccabm_cure_rate_path': 'cc_account_by_month/cc_account_by_month_001/cure_rate/', 'parquet_block_size': '512', 'aps_dedup_treasury_charge_off': 'account_portfolios_refi/account_portfolios_refi_001/account_portfolios_refi/dedup_treasury_charge_off', 'apu_dedup_treasury_charge_off': 'account_portfolios_uil/account_portfolios_uil_001/account_portfolios_uil/dedup_treasury_charge_off', 'aps_dedup_interest_rate_schedule': 'account_portfolios_refi/account_portfolios_refi_001/account_portfolios_refi/dedup_interest_rate', 'aps_dedup_original_installment': 'account_portfolios_refi/account_portfolios_refi_001/account_portfolios_refi/dedup_original_installment', 'apu_dedup_original_installment': 'account_portfolios_uil/account_portfolios_uil_001/account_portfolios_uil/dedup_original_installment', 'responsys_external_customer_path': 'avant/customer/customer_001/customer/', 'apu_dedup_interest_rate_schedule': 'account_portfolios_uil/account_portfolios_uil_001/account_portfolios_uil/dedup_interest_rate', 'aps_dedup_balances': 'account_portfolios_refi/account_portfolios_refi_001/account_portfolios_refi/dedup_balances', 'apu_dedup_balances': 'account_portfolios_uil/account_portfolios_uil_001/account_portfolios_uil/dedup_balances', 'verifications_queue_vds_path_history': 'avant.{}.dw.dw_orig_history.verifications_queue_session_history', 'responsys_007_raw_vds_path': 'avant.{}.dl.responsys.responsys_007', 'responsys_007_raw_pds_path': 'avantdlds-partner01-nonprod.avantdlds-partner01-{}-raw-bucket.responsys.responsys_007', 'responsys_008_raw_vds_path': 'avant.{}.dl.responsys.responsys_008', 'aps_dedup_loan_financial_owner': 'account_portfolios_refi/account_portfolios_refi_001/account_portfolios_refi/dedup_loan_financial_owner', 'responsys_010_key_path_limiter': '6987_OPT_OUT', 'verification_stage_session_dedup_file': 'verifications/verifications_011/dedupe_verification_stage_session', 'verification_queue_session_dedup_file': 'verifications/verifications_010/dedupe_verification_queue_session', 'responsys_log_file_name': 'responsys_019_transform_31510_1_20230224.log', 'status_dict': "{'step_1': 'Landed', 'step_2': 'Ingested', 'step_3': 'Registered', 'step_4': 'Staged', 'step_5': 'Transformed', 'step_6': 'Expired', 'step_7': 'Rejected', 'step_8':'Transform_raw'}", 'responsys_007_file_name': 'responsys_007_31510_1_20230224.pq', 'responsys_007_key_path_limiter': '6987_LAUNCH_STATE', 'responsys_007_raw': 'responsys/responsys_007/2023/02/24', 'responsys_008_file_name': 'responsys_008_31510_1_20230224.pq', 'responsys_008_key_path_limiter': '6987_OPEN', 'responsys_008_raw': 'responsys/responsys_008/2023/02/24', 'responsys_009_file_name': 'responsys_009_31510_1_20230224.pq', 'responsys_009_key_path_limiter': '6987_OPT_IN', 'responsys_009_raw': 'responsys/responsys_009/2023/02/24', 'responsys_010_file_name': 'responsys_010_31510_1_20230224.pq', 'responsys_010_raw': 'responsys/responsys_010/2023/02/24', 'responsys_011_file_name': 'responsys_011_31510_1_20230224.pq', 'responsys_011_key_path_limiter': '6987_PROGRAM', 'responsys_011_raw': 'responsys/responsys_011/2023/02/24', 'responsys_012_file_name': 'responsys_012_31510_1_20230224.pq', 'responsys_012_key_path_limiter': '6987_PROGRAM_STATE', 'responsys_009_raw_vds_path': 'avant.{}.dl.responsys.responsys_009', 'responsys_009_raw_pds_path': 'avantdlds-partner01-nonprod.avantdlds-partner01-{}-raw-bucket.responsys.responsys_009', 'responsys_010_raw_vds_path': 'avant.{}.dl.responsys.responsys_010', 'responsys_011_raw_vds_path': 'avant.{}.dl.responsys.responsys_011', 'responsys_001_file_name': 'responsys_001_31510_1_20230224.pq', 'responsys_001_key_path_limiter': '6987_BOUNCE', 'responsys_001_raw': 'responsys/responsys_001/2023/02/24', 'responsys_002_file_name': 'responsys_002_31510_1_20230224.pq', 'responsys_002_key_path_limiter': '6987_CLICK', 'responsys_002_raw': 'responsys/responsys_002/2023/02/24', 'responsys_003_file_name': 'responsys_003_31510_1_20230224.pq', 'responsys_003_key_path_limiter': '6987_COMPLAINT', 'responsys_003_raw': 'responsys/responsys_003/2023/02/24', 'responsys_002_raw_vds_path': 'avant.{}.dl.responsys.responsys_002', 'apu_dedup_loan_financial_owner': 'account_portfolios_uil/account_portfolios_uil_001/account_portfolios_uil/dedup_loan_financial_owner', 'aps_dedup_loan_servicing_settlement': 'account_portfolios_refi/account_portfolios_refi_001/account_portfolios_refi/dedup_loan_servicing_settlement', 'apu_dedup_loan_servicing_settlement': 'account_portfolios_uil/account_portfolios_uil_001/account_portfolios_uil/dedup_loan_servicing_settlement', 'aps_dedup_loan_debt_sale': 'account_portfolios_refi/account_portfolios_refi_001/account_portfolios_refi/dedup_loan_debt_sale', 'apu_dedup_loan_debt_sale': 'account_portfolios_uil/account_portfolios_uil_001/account_portfolios_uil/dedup_loan_debt_sale', 'responsys_004_file_name': 'responsys_004_31510_1_20230224.pq', 'responsys_004_key_path_limiter': '6987_CONVERT', 'responsys_004_raw': 'responsys/responsys_004/2023/02/24', 'responsys_005_file_name': 'responsys_005_31510_1_20230224.pq', 'responsys_005_key_path_limiter': '6987_FAIL', 'responsys_005_raw': 'responsys/responsys_005/2023/02/24', 'responsys_006_file_name': 'responsys_006_31510_1_20230224.pq', 'responsys_006_key_path_limiter': '6987_FORM', 'responsys_006_raw': 'responsys/responsys_006/2023/02/24', 'responsys_003_raw_vds_path': 'avant.{}.dl.responsys.responsys_003', 'responsys_004_raw_vds_path': 'avant.{}.dl.responsys.responsys_004', 'responsys_004_raw_pds_path': 'avantdlds-partner01-nonprod.avantdlds-partner01-{}-raw-bucket.responsys.responsys_004', 'responsys_005_raw_vds_path': 'avant.{}.dl.responsys.responsys_005', 'aps_dedup_loan_payment_plan': 'account_portfolios_refi/account_portfolios_refi_001/account_portfolios_refi/dedup_loan_payment_plan', 'apu_dedup_loan_payment_plan': 'account_portfolios_uil/account_portfolios_uil_001/account_portfolios_uil/dedup_loan_payment_plan', 'responsys_013_file_name': 'responsys_013_31510_1_20230224.pq', 'responsys_013_key_path_limiter': '6987_PUSH_CONVERTED', 'responsys_013_raw': 'responsys/responsys_013/2023/02/24', 'responsys_014_file_name': 'responsys_014_31510_1_20230224.pq', 'responsys_014_key_path_limiter': '6987_PUSH_FAILED', 'responsys_014_raw': 'responsys/responsys_014/2023/02/24', 'responsys_015_file_name': 'responsys_015_31510_1_20230224.pq', 'responsys_015_key_path_limiter': '6987_PUSH_OPENED', 'responsys_015_raw': 'responsys/responsys_015/2023/02/24', 'responsys_016_file_name': 'responsys_016_31510_1_20230224.pq', 'responsys_012_raw_vds_path': 'avant.{}.dl.responsys.responsys_012', 'responsys_013_raw_vds_path': 'avant.{}.dl.responsys.responsys_013', 'responsys_014_raw_vds_path': 'avant.{}.dl.responsys.responsys_014', 'responsys_015_raw_vds_path': 'avant.{}.dl.responsys.responsys_015', 'responsys_016_key_path_limiter': '6987_PUSH_SENT', 'responsys_016_raw': 'responsys/responsys_016/2023/02/24', 'responsys_017_file_name': 'responsys_017_31510_1_20230224.pq', 'responsys_017_key_path_limiter': '6987_PUSH_SKIPPED', 'responsys_017_raw': 'responsys/responsys_017/2023/02/24', 'responsys_018_file_name': 'responsys_018_31510_1_20230224.pq', 'responsys_018_key_path_limiter': '6987_SENT', 'responsys_018_raw': 'responsys/responsys_018/2023/02/24', 'responsys_019_file_name': 'responsys_019_31510_1_20230224.pq', 'responsys_019_key_path_limiter': '6987_SKIPPED', 'responsys_019_raw': 'responsys/responsys_019/2023/02/24', 'responsys_016_raw_vds_path': 'avant.{}.dl.responsys.responsys_016', 'responsys_017_raw_vds_path': 'avant.{}.dl.responsys.responsys_017', 'responsys_018_raw_vds_path': 'avant.{}.dl.responsys.responsys_018', 'responsys_019_raw_vds_path': 'avant.{}.dl.responsys.responsys_019', 'aps_dedup_operational_charge_off': 'account_portfolios_refi/account_portfolios_refi_001/account_portfolios_refi/dedup_operational_charge_off', 'apu_dedup_operational_charge_off': 'account_portfolios_uil/account_portfolios_uil_001/account_portfolios_uil/dedup_operational_charge_off', 'cc_account_by_day_dedup_file': 'cc_account_by_day/cc_account_by_day_001/dedup_cc_account_by_day', 'verifications_stage_vds_path_history': 'avant.{}.dw.dw_orig_history.verifications_stage_session_history', 'loan_by_day_final': 'loan_by_day/loan_by_day_001/loan_by_day', 'lexisnexis_bankruptcies_table': 'bankruptcy/bankruptcy_001/dedup_bankruptcy', 'lexisnexis_loan_cust_app_table': 'customer_application/customer_application_001/dedup_loan_customer_application', 'apu_dedup_active_installment': 'account_portfolios_uil/account_portfolios_uil_001/account_portfolios_uil/dedup_active_installment', 'aps_dedup_cancelled_loans': 'account_portfolios_refi/account_portfolios_refi_001/account_portfolios_refi/cancelled_loans/append_cancelled_loans', 'apu_dedup_cancelled_loans': 'account_portfolios_uil/account_portfolios_uil_001/account_portfolios_uil/cancelled_loans/append_cancelled_loans', 'aps_dedup_active_installment': 'account_portfolios_refi/account_portfolios_refi_001/account_portfolios_refi/dedup_active_installment', 'original_installment_union': 'account_portfolios_union/account_portfolios_union_001/original_installment/original_installment_union', 'cancelled_loans_union': 'account_portfolios_union/account_portfolios_union_001/cancelled_loans/cancelled_loans_union', 'interest_rate_union': 'account_portfolios_union/account_portfolios_union_001/interest_rate/interest_rate_union', 'treasury_charge_off_union': 'account_portfolios_union/account_portfolios_union_001/treasury_charge_off/treasury_charge_off_union', 'balances_union': 'loan_balance_by_day/loan_balance_by_day_001/balances_union/', 'verification_status_decision_dedup_file': 'verifications/verifications_009/dedupe_verifications_status_decision', 'dremio_security_table_path': 'Security.dremio_security_redesign', 'uil_raw_dedup_path': 'account_portfolios_uil/account_portfolios_uil_001/dedup_account_portfolios_uil/', 'refi_raw_dedup_path': 'account_portfolios_refi/account_portfolios_refi_001/dedup_account_portfolios_refi/', 'dedup_loan_transaction': 'loan_transaction/loan_transaction_003/dedup_loan_transaction', 'first_data_phase_two_daily_authorization_data_lake_dedup_file': 'first_data/first_data_014/dedup_daily_authorization', 'first_data_phase_two_security_master_work_1_data_lake_dedup_file': 'first_data/first_data_015/dedup_security_master_work_1', 'first_data_phase_two_security_master_work_4_data_lake_dedup_file': 'first_data/first_data_016/dedup_security_master_work_4', 'loan_financial_owner_union': 'account_portfolios_union/account_portfolios_union_001/loan_financial_owner/loan_financial_owner_union', 'loan_servicing_settlement_union': 'account_portfolios_union/account_portfolios_union_001/loan_servicing_settlement/loan_servicing_settlement_union', 'tco_reference_file_path': 'tco_reference/tco_ref_update.csv', 'decrypt_script_path': 'parallel_decrypt.py', 'fd_cc_lv_monetary_detail_cross_cycle_adjustment_data_lake_dedup_file': 'fd_cc_lv/fd_cc_lv_008/dedup_monetary_detail_cross_cycle_adjustment', 'fd_cc_lv_monetary_detail_current_cycle_adjustment_data_lake_dedup_file': 'fd_cc_lv/fd_cc_lv_009/dedup_monetary_detail_current_cycle_adjustment', 'fd_cc_lv_monetary_detail_transaction_data_lake_dedup_file': 'fd_cc_lv/fd_cc_lv_010/dedup_monetary_detail_transaction', 'operational_charge_off_v3_union': 'account_portfolios_union/account_portfolios_union_001/operational_charge_off/operational_charge_off_union', 'responsys_core_pds_path': 'avantdlds-partner01-nonprod.avantdlds-partner01-{}-transform-bucket.responsys.responsys_020.dedupe_core_responsys', 'responsys_core_vds_path': 'avant.{}.dw.dw_orig.core_responsys', 'tonic_url': 'https://tonic.k8s.services.global.avant.com', 'tonic_app_id': 'BRX5qfU6OvoB1WlilVTCjXaaJpDvFIFeqXtYgGBpFkxp9Q7frGMSXKGw89HhuWZv', 's3_bucket_process_start_time': '2023-02-24 16:06:26', 'file_id': 'responsys_018', 'vault_encrypt_path': 'app/landing_zone_encryption/amount/prod', 'secret_path': 'app/abc/dev', 'DREMIO_USERNAME': 'XXXXXXXXXX', 'DREMIO_PASSWORD': 'XXXXXXXXXX', 'ec2_role': 'airflow-role', 'role_name': 'avant-dlds-airflow-dev-ecs-task-role', 'emr_role_name': 'ec2_run_terraform', 'metadata_url_base': 'http://169.254.169.254', 'VAULT_URL': 'https://vault.shared.partner01.data.avant.com', 'source_file_creation_time': '2023-02-24 15:00:09', 'file_list': ['responsys/drop/6987_SENT_20230224_030002.txt.zip', 'responsys/drop/6987_SENT_20230224_150001.txt.zip'], 'current_year': '2023', 'current_month': '02', 'current_day': '24', 'current_hour': '16', 'batch_id': '31510', 'run_id': '1', 'key': 'file_id_responsys_018', 'business_date': '1970-01-20', 'file_creation_time': '1970-01-20 09:53:27', 'run_date': '20230224', 'feed_meta': 's3://avantdlds-partner01-dev-common-bucket/common/feed_metadata.cfg', 'cur_date': '2023/02/24', 'feed_attr': 's3://avantdlds-partner01-dev-common-bucket/common/feed_attr.cfg', 'env': 'dev', 'gpg_vault_version': 3, 'attribute_list': [], 'data_type_list': [('EVENT_TYPE_ID', 'integer'), ('ACCOUNT_ID', 'integer'), ('LIST_ID', 'integer'), ('RIID', 'long'), ('CUSTOMER_ID', 'long'), ('CAMPAIGN_ID', 'long'), ('LAUNCH_ID', 'long'), ('EMAIL', 'String'), ('EMAIL_ISP', 'String'), ('EMAIL_FORMAT', 'String'), ('OFFER_SIGNATURE_ID', 'integer'), ('DYNAMIC_CONTENT_SIGNATURE_ID', 'integer'), ('MESSAGE_SIZE', 'integer'), ('SEGMENT_INFO', 'String'), ('CONTACT_INFO', 'String'), ('AC_ID', 'long'), ('EVENT_CAPTURED_DT', 'String'), ('EVENT_STORED_DT', 'String'), ('EMAIL_DATE', 'String')], 'target_data_type_list': [('AC_ID', 'long'), ('ACCOUNT_ID', 'integer'), ('APP_ID', 'integer'), ('BOUNCE_TYPE', 'String'), ('BROWSER', 'String'), ('BROWSER_TYPE', 'String'), ('CAMPAIGN_ID', 'long'), ('CAMPAIGN_NAME', 'String'), ('COMPLAINER_EMAIL', 'String'), ('CONTACT_INFO', 'String'), ('CUSTOMER_ID', 'long'), ('DESCRIPTION', 'String'), ('EMAIL', 'String'), ('EMAIL_FORMAT', 'String'), ('EMAIL_ISP', 'String'), ('EVENT_UUID', 'String'), ('EXTERNAL_CAMPAIGN_ID', 'long'), ('FORM_NAME', 'String'), ('LAUNCH_CHARSET', 'String'), ('LAUNCH_ERROR_CODE', 'String'), ('LAUNCH_NAME', 'String'), ('LAUNCH_STATUS', 'String'), ('LAUNCH_TYPE', 'String'), ('LIST_ID', 'integer'), ('MARKETING_PROGRAM', 'String'), ('MARKETING_STRATEGY', 'String'), ('OFFER_CATEGORY', 'String'), ('OFFER_NAME', 'String'), ('LAUNCH_ID', 'long'), ('DYNAMIC_CONTENT_SIGNATURE_ID', 'integer'), ('ENACTMENT_ID', 'long'), ('EVENT_TYPE_ID', 'integer'), ('FORM_ID', 'long'), ('MESSAGE_SIZE', 'integer'), ('OFFER_NUMBER', 'long'), ('OFFER_SIGNATURE_ID', 'integer'), ('OFFER_URL', 'String'), ('OPERATING_SYSTEM', 'String'), ('ORDER_ID', 'integer'), ('ORDER_QUANTITY', 'integer'), ('ORDER_TOTAL', 'double'), ('PLATFORM_TYPE', 'String'), ('PRODUCT_CATEGORY', 'String'), ('PRODUCT_TYPE', 'String'), ('PROGRAM_DESCRIPTION', 'String'), ('PROGRAM_NAME', 'String'), ('PURPOSE', 'String'), ('PUSH_ID', 'integer'), ('PUSHIO_API_KEY', 'String'), ('REASON', 'String'), ('REASON_CODE', 'String'), ('RIID', 'long'), ('SEGMENT_INFO', 'String'), ('SOURCE', 'String'), ('SPAM_TYPE', 'String'), ('SUBJECT', 'String'), ('USER_AGENT_STRING', 'String'), ('USER_ID', 'integer'), ('PROGRAM_VERSION', 'integer'), ('PROGRAM_ID', 'long'), ('SF_CAMPAIGN_ID', 'long'), ('COMPLAINT_DT', 'String'), ('EMAIL_DATE', 'String'), ('EVENT_CAPTURED_DT', 'String'), ('EVENT_STORED_DT', 'String'), ('LAUNCH_COMPLETED_DT', 'String'), ('LAUNCH_STARTED_DT', 'String')], 'partner_id': 'partner01', 'sub_partner': 'avant', 'dag_name': 'responsys', 'application_sub_name': 'responsys_018', 'job_id': 310218, 'program_name': 'responsys_ingest_to_transient.py', 'DREMIO_SERVER_URL': 'https://dremio-nonprod.services.global.avant.com', 'file_number': '18'}, 'responsys_019': {'feed_attribute_object': 'common/feed_attr.cfg', 'feed_metadata_object': 'common/feed_metadata.cfg', 'uow_dependency_object': 'common/uow_dependency.cfg', 'uow_error_object': 'common/uow_error.cfg', 'verifications_queue_vds_path': 'avant.{}.dw.dw_orig.verifications_queue_session', 'responsys_pds_path': 'avantdlds-partner01-nonprod.avantdlds-partner01-{}-transform-bucket.responsys.responsys_020.dedupe_responsys', 'responsys_012_raw_pds_path': 'avantdlds-partner01-nonprod.avantdlds-partner01-{}-raw-bucket.responsys.responsys_012', 'responsys_data_path': 'responsys/responsys/2023/02/24', 'responsys_012_raw': 'responsys/responsys_012/2023/02/24', 'MasterSecurityGroupName': 'AirflowEMRMasterSG', 'SlaveSecurityGroupName': 'AirflowEMRSlaveSG', 'SubnetKeyName': 'data-partner01-{}-private-app-2a', 'DB_CLUSTER_IDENTIFIER': 'auroraclusteroperational', 'instance_profile_role': 'ec2_run_terraform', 'service_role': 'EC_EMR_DEFAULTBBI', 'auto_scaling_role': 'EC_EMR_DEFAULTBBI', 'EMR_EC_PEM_FILE': 'EC2_BBI_DEV', 'ServiceSecurityGroupName': 'AirflowServiceSecurityGroup', 'common_bucket': 'avantdlds-partner01-dev-common-bucket', 'exception_bucket': 'avantdlds-partner01-dev-exception-bucket', 'log_bucket': 'avantdlds-partner01-dev-log-bucket', 'verifications_stage_vds_path': 'avant.{}.dw.dw_orig.verifications_stage_session', 'aws_read_shared_vpc': 'arn:aws:iam::336913029742:role/admin_access_for_{}_from_shared', 'workflow_file_id': 'workflow_001', 'workflow_application': 'workflow', 'avant_reproc_source_type': 'Reproc', 'loaded_by': 'avantadmin', 'config_file_name': 'common/feed_metadata.cfg', 'parameter_config_file': 'common/parameters.cfg', 'region': 'us-east-2', 'feed_attribute_config_file': 'common/feed_attr.cfg', 'helpscout_batch_conversation_file_id': 'helpscout_001', 'helpscout_batch_threads_file_id': 'helpscout_002', 'mailbox_csv_path': '/common/Mailboxes.csv', 'cluster_id': 'cluster_id', 'spark_application_type': 'pyspark', 'aws_connection_id': 'aws_default', 'ref_data_object': 'common/reference_data.cfg', 'dremio_security_table_name': 'dremio_security', 'OPS_TABLE_S3_BUCKET_TABLE': 'S3_BUCKET_TABLE', 'OPS_TABLE_BATCH_RUN_STATS': 'BATCH_RUN_STATS', 'OPS_TABLE_BATCH_REPORTS': 'BATCH_REPORTS', 'transunion_account_review_file_id': 'transunion_001', 'transunion_account_review_application': 'transunion', 'EMAIL_RESPONSE_SLA_PATH': 'common/Email_Response_SLA.csv', 'landing_prefix_path': 'responsys/drop', 'loan_by_day': 'loan_by_day/loan_by_day_003/dedup_loan_by_day/', 'loan_payment_plan_v3_union': 'account_portfolios_union/account_portfolios_union_001/loan_payment_plan/loan_payment_plan_union', 'dedup_loan_by_day': 'loan_by_day/loan_by_day_003/dedup_loan_by_day', 'loan_financial_owner_v3_union': 'account_portfolios_union/account_portfolios_union_001/loan_financial_owner/loan_financial_owner_union', 'loan_by_day_v3': 'loan_by_day/loan_by_day_003/dedup_loan_by_day/', 'raw_loan_by_day': 'loan_by_day/loan_by_day_003/loan_by_day/*/*/*/*/*/', 'dedup_loan_balance_by_day': 'loan_balance_by_day/loan_balance_by_day_001/loan_balance_by_day/', 'responsys_log_file_path': 'log/responsys/responsys_019/2023/02/24', 'responsys_vds_path': 'avant.{}.dw.dw_orig.responsys', 'first_data_monetary_detail_charge_off_data_lake_dedup_file': 'first_data/first_data_007/dedup_monetary_detail_charge_off', 'first_data_monetary_detail_cross_cycle_adjustment_data_lake_dedup_file': 'first_data/first_data_008/dedup_monetary_detail_cross_cycle_adjustment', 'first_data_monetary_detail_current_cycle_adjustment_data_lake_dedup_file': 'first_data/first_data_009/dedup_monetary_detail_current_cycle_adjustment', 'loan_customer_application_history_l0_vds_path_intermediate': 'avant.{}.intermediate.dw.dw_orig_history.loan_customer_application_history_l0', 'first_data_monetary_detail_transaction_data_lake_dedup_file': 'first_data/first_data_010/dedup_monetary_detail_transaction', 'first_data_fraud_falcon_data_lake_dedup_file': 'first_data/first_data_005/dedup_fraud_falcon', 'raw_bucket': 'avantdlds-partner01-dev-raw-bucket', 'stage_bucket': 'avantdlds-partner01-dev-stage-bucket', 'transform_bucket': 'avantdlds-partner01-dev-transform-bucket', 'transient_bucket': 'avantdlds-partner01-dev-transient-bucket', 'outgoing_bucket': 'avantdlds-partner01-dev-outgoing-bucket', 'first_data_historical_cardholder_data_data_lake_dedup_file': 'first_data/first_data_006/dedup_historical_cardholder_data', 'first_data_account_data_lake_dedup_file': 'first_data/first_data_001/dedup_account', 'first_data_account_delinquency_data_lake_dedup_file': 'first_data/first_data_002/dedup_account_delinquency', 'fd_cc_lv_account_data_lake_dedup_file': 'fd_cc_lv/fd_cc_lv_001/dedup_account', 'fd_cc_lv_account_delinquency_data_lake_dedup_file': 'fd_cc_lv/fd_cc_lv_002/dedup_account_delinquency', 'fd_cc_lv_account_delinquency_items_data_lake_dedup_file': 'fd_cc_lv/fd_cc_lv_003/dedup_account_delinquency_items', 'fd_cc_lv_current_monetary_activity_data_lake_dedup_file': 'fd_cc_lv/fd_cc_lv_004/dedup_current_monetary_activity', 'first_data_account_delinquency_items_data_lake_dedup_file': 'first_data/first_data_003/dedup_account_delinquency_items', 'drop_bucket': 'avant-partner01-landing', 'first_data_current_monetary_activity_data_lake_dedup_file': 'first_data/first_data_004/dedup_current_monetary_activity', 'responsys_001_raw_vds_path': 'avant.{}.dl.responsys.responsys_001', 'key_path': '[0-9]{4}_SKIPPED_[0-9]{8}_[0-9]{6}.txt.zip', 'responsys_002_raw_pds_path': 'avantdlds-partner01-nonprod.avantdlds-partner01-{}-raw-bucket.responsys.responsys_002', 'cust_app_dedup_file': 'customer_application/customer_application_001/dedup_loan_customer_application', 'cust_app_experiment_dedup_file': 'customer_application/customer_application_005/dedup_loan_customer_application_experiment', 'responsys_005_raw_pds_path': 'avantdlds-partner01-nonprod.avantdlds-partner01-{}-raw-bucket.responsys.responsys_005', 'dremio_security_redesign': '"Security".dremio_security_redesign', 'cca_cust_app_dedup_file': 'credit_card_customer_application/credit_card_customer_application_001/dedup_cc_account_customer_application', 'fd_cc_lv_fraud_falcon_data_lake_dedup_file': 'fd_cc_lv/fd_cc_lv_005/dedup_fraud_falcon', 'responsys_010_raw_pds_path': 'avantdlds-partner01-nonprod.avantdlds-partner01-{}-raw-bucket.responsys.responsys_010', 'responsys_stage_log_file_name': 'responsys_019_stage_31507_1_20230224.log', 'responsys_011_raw_pds_path': 'avantdlds-partner01-nonprod.avantdlds-partner01-{}-raw-bucket.responsys.responsys_011', 'responsys_013_raw_pds_path': 'avantdlds-partner01-nonprod.avantdlds-partner01-{}-raw-bucket.responsys.responsys_013', 'responsys_014_raw_pds_path': 'avantdlds-partner01-nonprod.avantdlds-partner01-{}-raw-bucket.responsys.responsys_014', 'responsys_015_raw_pds_path': 'avantdlds-partner01-nonprod.avantdlds-partner01-{}-raw-bucket.responsys.responsys_015', 'responsys_016_raw_pds_path': 'avantdlds-partner01-nonprod.avantdlds-partner01-{}-raw-bucket.responsys.responsys_016', 'responsys_017_raw_pds_path': 'avantdlds-partner01-nonprod.avantdlds-partner01-{}-raw-bucket.responsys.responsys_017', 'partner01_source': 'avantdlds-partner01-nonprod', 'workflow_script_sessions': 'pyspark/workflow/pyspark/workflow_session.py', 'workflow_script_session_types': 'pyspark/workflow/pyspark/workflow_type_session.py', 'workflow_script_validations': 'pyspark/workflow/pyspark/workflow_validation.py', 'workflow_script_step': 'pyspark/workflow/pyspark/workflow_step.py', 'dedup_loan_transcation_v3': 'loan_transaction/loan_transaction_003/dedup_loan_transaction/', 'verification_stage_session_join_data_path': 'verifications/verifications_011/join_verification_stage_session', 'verification_queue_session_join_data_path': 'verifications/verifications_010/join_verification_queue_session', 'avant_source_type': 'Regular', 'responsys_018_raw_pds_path': 'avantdlds-partner01-nonprod.avantdlds-partner01-{}-raw-bucket.responsys.responsys_018', 'responsys_019_raw_pds_path': 'avantdlds-partner01-nonprod.avantdlds-partner01-{}-raw-bucket.responsys.responsys_019', 'fd_cc_lv_historical_cardholder_data_data_lake_dedup_file': 'fd_cc_lv/fd_cc_lv_006/dedup_historical_cardholder_data', 'fd_cc_lv_monetary_detail_charge_off_data_lake_dedup_file': 'fd_cc_lv/fd_cc_lv_007/dedup_monetary_detail_charge_off', 'af_dremio_hostname_nonprod': 'ip-10-240-8-173.us-east-2.compute.internal', 'af_dremio_hostname_prod': 'ip-10-240-6-103.us-east-2.compute.internal', 'responsys_001_raw_pds_path': 'avantdlds-partner01-nonprod.avantdlds-partner01-{}-raw-bucket.responsys.responsys_001', 'responsys_003_raw_pds_path': 'avantdlds-partner01-nonprod.avantdlds-partner01-{}-raw-bucket.responsys.responsys_003', 'responsys_006_raw_vds_path': 'avant.{}.dl.responsys.responsys_006', 'responsys_006_raw_pds_path': 'avantdlds-partner01-nonprod.avantdlds-partner01-{}-raw-bucket.responsys.responsys_006', 'responsys_008_raw_pds_path': 'avantdlds-partner01-nonprod.avantdlds-partner01-{}-raw-bucket.responsys.responsys_008', 'ccabm_cure_rate_path': 'cc_account_by_month/cc_account_by_month_001/cure_rate/', 'parquet_block_size': '512', 'aps_dedup_treasury_charge_off': 'account_portfolios_refi/account_portfolios_refi_001/account_portfolios_refi/dedup_treasury_charge_off', 'apu_dedup_treasury_charge_off': 'account_portfolios_uil/account_portfolios_uil_001/account_portfolios_uil/dedup_treasury_charge_off', 'aps_dedup_interest_rate_schedule': 'account_portfolios_refi/account_portfolios_refi_001/account_portfolios_refi/dedup_interest_rate', 'aps_dedup_original_installment': 'account_portfolios_refi/account_portfolios_refi_001/account_portfolios_refi/dedup_original_installment', 'apu_dedup_original_installment': 'account_portfolios_uil/account_portfolios_uil_001/account_portfolios_uil/dedup_original_installment', 'responsys_external_customer_path': 'avant/customer/customer_001/customer/', 'apu_dedup_interest_rate_schedule': 'account_portfolios_uil/account_portfolios_uil_001/account_portfolios_uil/dedup_interest_rate', 'aps_dedup_balances': 'account_portfolios_refi/account_portfolios_refi_001/account_portfolios_refi/dedup_balances', 'apu_dedup_balances': 'account_portfolios_uil/account_portfolios_uil_001/account_portfolios_uil/dedup_balances', 'verifications_queue_vds_path_history': 'avant.{}.dw.dw_orig_history.verifications_queue_session_history', 'responsys_007_raw_vds_path': 'avant.{}.dl.responsys.responsys_007', 'responsys_007_raw_pds_path': 'avantdlds-partner01-nonprod.avantdlds-partner01-{}-raw-bucket.responsys.responsys_007', 'responsys_008_raw_vds_path': 'avant.{}.dl.responsys.responsys_008', 'aps_dedup_loan_financial_owner': 'account_portfolios_refi/account_portfolios_refi_001/account_portfolios_refi/dedup_loan_financial_owner', 'responsys_010_key_path_limiter': '6987_OPT_OUT', 'verification_stage_session_dedup_file': 'verifications/verifications_011/dedupe_verification_stage_session', 'verification_queue_session_dedup_file': 'verifications/verifications_010/dedupe_verification_queue_session', 'responsys_log_file_name': 'responsys_019_transform_31507_1_20230224.log', 'status_dict': "{'step_1': 'Landed', 'step_2': 'Ingested', 'step_3': 'Registered', 'step_4': 'Staged', 'step_5': 'Transformed', 'step_6': 'Expired', 'step_7': 'Rejected', 'step_8':'Transform_raw'}", 'responsys_007_file_name': 'responsys_007_31507_1_20230224.pq', 'responsys_007_key_path_limiter': '6987_LAUNCH_STATE', 'responsys_007_raw': 'responsys/responsys_007/2023/02/24', 'responsys_008_file_name': 'responsys_008_31507_1_20230224.pq', 'responsys_008_key_path_limiter': '6987_OPEN', 'responsys_008_raw': 'responsys/responsys_008/2023/02/24', 'responsys_009_file_name': 'responsys_009_31507_1_20230224.pq', 'responsys_009_key_path_limiter': '6987_OPT_IN', 'responsys_009_raw': 'responsys/responsys_009/2023/02/24', 'responsys_010_file_name': 'responsys_010_31507_1_20230224.pq', 'responsys_010_raw': 'responsys/responsys_010/2023/02/24', 'responsys_011_file_name': 'responsys_011_31507_1_20230224.pq', 'responsys_011_key_path_limiter': '6987_PROGRAM', 'responsys_011_raw': 'responsys/responsys_011/2023/02/24', 'responsys_012_file_name': 'responsys_012_31507_1_20230224.pq', 'responsys_012_key_path_limiter': '6987_PROGRAM_STATE', 'responsys_009_raw_vds_path': 'avant.{}.dl.responsys.responsys_009', 'responsys_009_raw_pds_path': 'avantdlds-partner01-nonprod.avantdlds-partner01-{}-raw-bucket.responsys.responsys_009', 'responsys_010_raw_vds_path': 'avant.{}.dl.responsys.responsys_010', 'responsys_011_raw_vds_path': 'avant.{}.dl.responsys.responsys_011', 'responsys_001_file_name': 'responsys_001_31507_1_20230224.pq', 'responsys_001_key_path_limiter': '6987_BOUNCE', 'responsys_001_raw': 'responsys/responsys_001/2023/02/24', 'responsys_002_file_name': 'responsys_002_31507_1_20230224.pq', 'responsys_002_key_path_limiter': '6987_CLICK', 'responsys_002_raw': 'responsys/responsys_002/2023/02/24', 'responsys_003_file_name': 'responsys_003_31507_1_20230224.pq', 'responsys_003_key_path_limiter': '6987_COMPLAINT', 'responsys_003_raw': 'responsys/responsys_003/2023/02/24', 'responsys_002_raw_vds_path': 'avant.{}.dl.responsys.responsys_002', 'apu_dedup_loan_financial_owner': 'account_portfolios_uil/account_portfolios_uil_001/account_portfolios_uil/dedup_loan_financial_owner', 'aps_dedup_loan_servicing_settlement': 'account_portfolios_refi/account_portfolios_refi_001/account_portfolios_refi/dedup_loan_servicing_settlement', 'apu_dedup_loan_servicing_settlement': 'account_portfolios_uil/account_portfolios_uil_001/account_portfolios_uil/dedup_loan_servicing_settlement', 'aps_dedup_loan_debt_sale': 'account_portfolios_refi/account_portfolios_refi_001/account_portfolios_refi/dedup_loan_debt_sale', 'apu_dedup_loan_debt_sale': 'account_portfolios_uil/account_portfolios_uil_001/account_portfolios_uil/dedup_loan_debt_sale', 'responsys_004_file_name': 'responsys_004_31507_1_20230224.pq', 'responsys_004_key_path_limiter': '6987_CONVERT', 'responsys_004_raw': 'responsys/responsys_004/2023/02/24', 'responsys_005_file_name': 'responsys_005_31507_1_20230224.pq', 'responsys_005_key_path_limiter': '6987_FAIL', 'responsys_005_raw': 'responsys/responsys_005/2023/02/24', 'responsys_006_file_name': 'responsys_006_31507_1_20230224.pq', 'responsys_006_key_path_limiter': '6987_FORM', 'responsys_006_raw': 'responsys/responsys_006/2023/02/24', 'responsys_003_raw_vds_path': 'avant.{}.dl.responsys.responsys_003', 'responsys_004_raw_vds_path': 'avant.{}.dl.responsys.responsys_004', 'responsys_004_raw_pds_path': 'avantdlds-partner01-nonprod.avantdlds-partner01-{}-raw-bucket.responsys.responsys_004', 'responsys_005_raw_vds_path': 'avant.{}.dl.responsys.responsys_005', 'aps_dedup_loan_payment_plan': 'account_portfolios_refi/account_portfolios_refi_001/account_portfolios_refi/dedup_loan_payment_plan', 'apu_dedup_loan_payment_plan': 'account_portfolios_uil/account_portfolios_uil_001/account_portfolios_uil/dedup_loan_payment_plan', 'responsys_013_file_name': 'responsys_013_31507_1_20230224.pq', 'responsys_013_key_path_limiter': '6987_PUSH_CONVERTED', 'responsys_013_raw': 'responsys/responsys_013/2023/02/24', 'responsys_014_file_name': 'responsys_014_31507_1_20230224.pq', 'responsys_014_key_path_limiter': '6987_PUSH_FAILED', 'responsys_014_raw': 'responsys/responsys_014/2023/02/24', 'responsys_015_file_name': 'responsys_015_31507_1_20230224.pq', 'responsys_015_key_path_limiter': '6987_PUSH_OPENED', 'responsys_015_raw': 'responsys/responsys_015/2023/02/24', 'responsys_016_file_name': 'responsys_016_31507_1_20230224.pq', 'responsys_012_raw_vds_path': 'avant.{}.dl.responsys.responsys_012', 'responsys_013_raw_vds_path': 'avant.{}.dl.responsys.responsys_013', 'responsys_014_raw_vds_path': 'avant.{}.dl.responsys.responsys_014', 'responsys_015_raw_vds_path': 'avant.{}.dl.responsys.responsys_015', 'responsys_016_key_path_limiter': '6987_PUSH_SENT', 'responsys_016_raw': 'responsys/responsys_016/2023/02/24', 'responsys_017_file_name': 'responsys_017_31507_1_20230224.pq', 'responsys_017_key_path_limiter': '6987_PUSH_SKIPPED', 'responsys_017_raw': 'responsys/responsys_017/2023/02/24', 'responsys_018_file_name': 'responsys_018_31507_1_20230224.pq', 'responsys_018_key_path_limiter': '6987_SENT', 'responsys_018_raw': 'responsys/responsys_018/2023/02/24', 'responsys_019_file_name': 'responsys_019_31507_1_20230224.pq', 'responsys_019_key_path_limiter': '6987_SKIPPED', 'responsys_019_raw': 'responsys/responsys_019/2023/02/24', 'responsys_016_raw_vds_path': 'avant.{}.dl.responsys.responsys_016', 'responsys_017_raw_vds_path': 'avant.{}.dl.responsys.responsys_017', 'responsys_018_raw_vds_path': 'avant.{}.dl.responsys.responsys_018', 'responsys_019_raw_vds_path': 'avant.{}.dl.responsys.responsys_019', 'aps_dedup_operational_charge_off': 'account_portfolios_refi/account_portfolios_refi_001/account_portfolios_refi/dedup_operational_charge_off', 'apu_dedup_operational_charge_off': 'account_portfolios_uil/account_portfolios_uil_001/account_portfolios_uil/dedup_operational_charge_off', 'cc_account_by_day_dedup_file': 'cc_account_by_day/cc_account_by_day_001/dedup_cc_account_by_day', 'verifications_stage_vds_path_history': 'avant.{}.dw.dw_orig_history.verifications_stage_session_history', 'loan_by_day_final': 'loan_by_day/loan_by_day_001/loan_by_day', 'lexisnexis_bankruptcies_table': 'bankruptcy/bankruptcy_001/dedup_bankruptcy', 'lexisnexis_loan_cust_app_table': 'customer_application/customer_application_001/dedup_loan_customer_application', 'apu_dedup_active_installment': 'account_portfolios_uil/account_portfolios_uil_001/account_portfolios_uil/dedup_active_installment', 'aps_dedup_cancelled_loans': 'account_portfolios_refi/account_portfolios_refi_001/account_portfolios_refi/cancelled_loans/append_cancelled_loans', 'apu_dedup_cancelled_loans': 'account_portfolios_uil/account_portfolios_uil_001/account_portfolios_uil/cancelled_loans/append_cancelled_loans', 'aps_dedup_active_installment': 'account_portfolios_refi/account_portfolios_refi_001/account_portfolios_refi/dedup_active_installment', 'original_installment_union': 'account_portfolios_union/account_portfolios_union_001/original_installment/original_installment_union', 'cancelled_loans_union': 'account_portfolios_union/account_portfolios_union_001/cancelled_loans/cancelled_loans_union', 'interest_rate_union': 'account_portfolios_union/account_portfolios_union_001/interest_rate/interest_rate_union', 'treasury_charge_off_union': 'account_portfolios_union/account_portfolios_union_001/treasury_charge_off/treasury_charge_off_union', 'balances_union': 'loan_balance_by_day/loan_balance_by_day_001/balances_union/', 'verification_status_decision_dedup_file': 'verifications/verifications_009/dedupe_verifications_status_decision', 'dremio_security_table_path': 'Security.dremio_security_redesign', 'uil_raw_dedup_path': 'account_portfolios_uil/account_portfolios_uil_001/dedup_account_portfolios_uil/', 'refi_raw_dedup_path': 'account_portfolios_refi/account_portfolios_refi_001/dedup_account_portfolios_refi/', 'dedup_loan_transaction': 'loan_transaction/loan_transaction_003/dedup_loan_transaction', 'first_data_phase_two_daily_authorization_data_lake_dedup_file': 'first_data/first_data_014/dedup_daily_authorization', 'first_data_phase_two_security_master_work_1_data_lake_dedup_file': 'first_data/first_data_015/dedup_security_master_work_1', 'first_data_phase_two_security_master_work_4_data_lake_dedup_file': 'first_data/first_data_016/dedup_security_master_work_4', 'loan_financial_owner_union': 'account_portfolios_union/account_portfolios_union_001/loan_financial_owner/loan_financial_owner_union', 'loan_servicing_settlement_union': 'account_portfolios_union/account_portfolios_union_001/loan_servicing_settlement/loan_servicing_settlement_union', 'tco_reference_file_path': 'tco_reference/tco_ref_update.csv', 'decrypt_script_path': 'parallel_decrypt.py', 'fd_cc_lv_monetary_detail_cross_cycle_adjustment_data_lake_dedup_file': 'fd_cc_lv/fd_cc_lv_008/dedup_monetary_detail_cross_cycle_adjustment', 'fd_cc_lv_monetary_detail_current_cycle_adjustment_data_lake_dedup_file': 'fd_cc_lv/fd_cc_lv_009/dedup_monetary_detail_current_cycle_adjustment', 'fd_cc_lv_monetary_detail_transaction_data_lake_dedup_file': 'fd_cc_lv/fd_cc_lv_010/dedup_monetary_detail_transaction', 'operational_charge_off_v3_union': 'account_portfolios_union/account_portfolios_union_001/operational_charge_off/operational_charge_off_union', 'responsys_core_pds_path': 'avantdlds-partner01-nonprod.avantdlds-partner01-{}-transform-bucket.responsys.responsys_020.dedupe_core_responsys', 'responsys_core_vds_path': 'avant.{}.dw.dw_orig.core_responsys', 'tonic_url': 'https://tonic.k8s.services.global.avant.com', 'tonic_app_id': 'BRX5qfU6OvoB1WlilVTCjXaaJpDvFIFeqXtYgGBpFkxp9Q7frGMSXKGw89HhuWZv', 's3_bucket_process_start_time': '2023-02-24 16:06:26', 'file_id': 'responsys_019', 'vault_encrypt_path': 'app/landing_zone_encryption/amount/prod', 'secret_path': 'app/abc/dev', 'DREMIO_USERNAME': 'XXXXXXXXXX', 'DREMIO_PASSWORD': 'XXXXXXXXXX', 'ec2_role': 'airflow-role', 'role_name': 'avant-dlds-airflow-dev-ecs-task-role', 'emr_role_name': 'ec2_run_terraform', 'metadata_url_base': 'http://169.254.169.254', 'VAULT_URL': 'https://vault.shared.partner01.data.avant.com', 'source_file_creation_time': '2023-02-24 15:00:12', 'file_list': ['responsys/drop/6987_SKIPPED_20230224_030005.txt.zip', 'responsys/drop/6987_SKIPPED_20230224_150003.txt.zip'], 'current_year': '2023', 'current_month': '02', 'current_day': '24', 'current_hour': '16', 'batch_id': '31507', 'run_id': '1', 'key': 'file_id_responsys_019', 'business_date': '1970-01-20', 'file_creation_time': '1970-01-20 09:53:27', 'run_date': '20230224', 'feed_meta': 's3://avantdlds-partner01-dev-common-bucket/common/feed_metadata.cfg', 'cur_date': '2023/02/24', 'feed_attr': 's3://avantdlds-partner01-dev-common-bucket/common/feed_attr.cfg', 'env': 'dev', 'gpg_vault_version': 3, 'attribute_list': [], 'data_type_list': [('RIID', 'long'), ('CUSTOMER_ID', 'long'), ('CAMPAIGN_ID', 'long'), ('LAUNCH_ID', 'long'), ('EMAIL', 'String'), ('EMAIL_ISP', 'String'), ('EMAIL_FORMAT', 'String'), ('OFFER_SIGNATURE_ID', 'integer'), ('DYNAMIC_CONTENT_SIGNATURE_ID', 'integer'), ('MESSAGE_SIZE', 'integer'), ('SEGMENT_INFO', 'String'), ('EVENT_TYPE_ID', 'integer'), ('ACCOUNT_ID', 'integer'), ('LIST_ID', 'integer'), ('CONTACT_INFO', 'String'), ('REASON', 'String'), ('AC_ID', 'long'), ('EVENT_CAPTURED_DT', 'String'), ('EVENT_STORED_DT', 'String'), ('EMAIL_DATE', 'String')], 'target_data_type_list': [('AC_ID', 'long'), ('ACCOUNT_ID', 'integer'), ('APP_ID', 'integer'), ('BOUNCE_TYPE', 'String'), ('BROWSER', 'String'), ('BROWSER_TYPE', 'String'), ('CAMPAIGN_ID', 'long'), ('CAMPAIGN_NAME', 'String'), ('COMPLAINER_EMAIL', 'String'), ('CONTACT_INFO', 'String'), ('CUSTOMER_ID', 'long'), ('DESCRIPTION', 'String'), ('EMAIL', 'String'), ('EMAIL_FORMAT', 'String'), ('EMAIL_ISP', 'String'), ('EVENT_UUID', 'String'), ('EXTERNAL_CAMPAIGN_ID', 'long'), ('FORM_NAME', 'String'), ('LAUNCH_CHARSET', 'String'), ('LAUNCH_ERROR_CODE', 'String'), ('LAUNCH_NAME', 'String'), ('LAUNCH_STATUS', 'String'), ('LAUNCH_TYPE', 'String'), ('LIST_ID', 'integer'), ('MARKETING_PROGRAM', 'String'), ('MARKETING_STRATEGY', 'String'), ('OFFER_CATEGORY', 'String'), ('OFFER_NAME', 'String'), ('LAUNCH_ID', 'long'), ('DYNAMIC_CONTENT_SIGNATURE_ID', 'integer'), ('ENACTMENT_ID', 'long'), ('EVENT_TYPE_ID', 'integer'), ('FORM_ID', 'long'), ('MESSAGE_SIZE', 'integer'), ('OFFER_NUMBER', 'long'), ('OFFER_SIGNATURE_ID', 'integer'), ('OFFER_URL', 'String'), ('OPERATING_SYSTEM', 'String'), ('ORDER_ID', 'integer'), ('ORDER_QUANTITY', 'integer'), ('ORDER_TOTAL', 'double'), ('PLATFORM_TYPE', 'String'), ('PRODUCT_CATEGORY', 'String'), ('PRODUCT_TYPE', 'String'), ('PROGRAM_DESCRIPTION', 'String'), ('PROGRAM_NAME', 'String'), ('PURPOSE', 'String'), ('PUSH_ID', 'integer'), ('PUSHIO_API_KEY', 'String'), ('REASON', 'String'), ('REASON_CODE', 'String'), ('RIID', 'long'), ('SEGMENT_INFO', 'String'), ('SOURCE', 'String'), ('SPAM_TYPE', 'String'), ('SUBJECT', 'String'), ('USER_AGENT_STRING', 'String'), ('USER_ID', 'integer'), ('PROGRAM_VERSION', 'integer'), ('PROGRAM_ID', 'long'), ('SF_CAMPAIGN_ID', 'long'), ('COMPLAINT_DT', 'String'), ('EMAIL_DATE', 'String'), ('EVENT_CAPTURED_DT', 'String'), ('EVENT_STORED_DT', 'String'), ('LAUNCH_COMPLETED_DT', 'String'), ('LAUNCH_STARTED_DT', 'String')], 'partner_id': 'partner01', 'sub_partner': 'avant', 'dag_name': 'responsys', 'application_sub_name': 'responsys_019', 'job_id': 310219, 'program_name': 'responsys_ingest_to_transient.py', 'DREMIO_SERVER_URL': 'https://dremio-nonprod.services.global.avant.com', 'file_number': '19'}, 'number_of_files': '19', 'FILE_NUMBERS': [1, 2, 3, 4, 5, 6, 7, 8, 10, 11, 12, 15, 16, 17, 18, 19]}
"""
Date : May 2020
Author :  Avant

Purpose : Pyspark code to perform transformations on the data based
        on timestamp columns
        - following are the tasks summary
        1. Reading the responsys dedupe history file from specified s3 path
        2. Creating two dfs like active and inactive
        3. Finding common customer id from both dfs and assigning values 
        4. Perform the transformation logic for new campaign ids as per
        5. Saving the parquet files in specified target s3 path
"""
import sys
import logging
import traceback
# from common_utils import common_functions as cf
# from common_utils import exception_helpers as eh
import json
# from common_utils import db_helpers
from pyspark.sql import SparkSession, DataFrame
from pyspark.sql.functions import *
from pyspark.sql.window import Window
from datetime import date, timedelta
from pyspark.sql import Window
from pyspark.sql.functions import *

# %%
SPARK = SparkSession.builder.appName(args['program_name']).getOrCreate()

# %%
s3 = 's3://avantcamp-partner01-prod-ingestion-bucket/avant/direct_mail/first_mail/7138/direct_mail_ingestion.pq/'
# Out:
# Starting Spark application
# <table>
# <tr><th>ID</th><th>YARN Application ID</th><th>Kind</th><th>State</th><th>Spark UI</th><th>Driver log</th><th>Current session?</th></tr><tr><td>0</td><td>application_1692886286177_0002</td><td>pyspark3</td><td>idle</td><td><a target="_blank" href="http://ip-10-240-119-99.us-east-2.compute.internal:20888/proxy/application_1692886286177_0002/">Link</a></td><td><a target="_blank" href="http://ip-10-240-119-23.us-east-2.compute.internal:8042/node/containerlogs/container_1692886286177_0002_01_000001/livy">Link</a></td><td>✔</td></tr></table>
# SparkSession available as 'spark'.

# %%
responsys_df = SPARK.read.parquet(s3)

# %%
raw_df = responsys_df.withColumn("send_id", lit("175"))

# %%
raw_df.select("send_id").show()
# Out:
# +-------+
# |send_id|
# +-------+
# |    175|
# |    175|
# |    175|
# |    175|
# |    175|
# |    175|
# |    175|
# |    175|
# |    175|
# |    175|
# |    175|
# |    175|
# |    175|
# |    175|
# |    175|
# |    175|
# |    175|
# |    175|
# |    175|
# |    175|
# +-------+
# only showing top 20 rows

# %%
raw_df = responsys_df.withColumn("campaign_name",when(col("campaign_name") == "202103_001R1", "202104_001R1").otherwise("2"))

# %%
raw_df.select("campaign_name").show()

# %%
s3://avantcamp-partner01-prod-ingestion-bucket/avant/direct_mail/first_mail/eligibility_source/

# %%
raw_df.write.mode('overwrite').parquet(
    path='s3://avantcamp-partner01-prod-ingestion-bucket/avant/direct_mail/first_mail/eligibility_source/7138/direct_mail_ingestion.pq/',
    compression='snappy'
)

# %%
raw_df.count()
# Out:
# 80799272
