# %%
from databricks import sql
import pandas as pd

def databricks_query_run(query):

    connection = sql.connect(
                            server_hostname = "avant-data-partner01-dev-use2-default.cloud.databricks.com",
                            http_path = "/sql/1.0/warehouses/05d5b5ba0edb9e4a",
                            access_token = "dapif2aab2f9a599ccf50d9b6adec22d1c1d")

    cursor = connection.cursor()

    cursor.execute(query)


    # Fetch all rows
    rows = cursor.fetchall()

    # Get column names
    columns = [desc[0] for desc in cursor.description]

    # Create DataFrame
    pandas_df = pd.DataFrame(rows, columns=columns)

    cursor.close()
    connection.close()

    return pandas_df

# %%
query = '''
select * from silver.intermediate.int_dropzone_customer_today
where id = 179527446
'''

blocking_customers = databricks_query_run(query)
pd.set_option('display.max_colwidth', None)

# %%
blocking_customers
# Out:
#           id                       created_at  \
# 0  179527446 2024-04-03 20:24:57.356747+00:00
#
#                         updated_at  customer_id  \
# 0 2024-04-03 20:24:57.547297+00:00    304269317
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                information  \
# 0  ---\n:data: !ruby/hash:ActiveRecordExt::Encryption::EncryptingHash\n  partial_application: !ruby/hash:ActiveRecordExt::Encryption::EncryptingHash\n    customer_application: !ruby/hash:ActiveRecordExt::Encryption::EncryptingHash\n      product_type: installment\n      loan_purpose: \n    customer_application_metadata: !ruby/hash:ActiveRecordExt::Encryption::EncryptingHash\n      acquisition_channel: \n      promo_code: \n      requested_loan_amount: \n      self_credit_score: \n      address_start_date: \n      address_start_date_month: \n      address_start_date_year: \n      credit_hard_pull_consent: \n      income_start_date: \n      income_start_date_month: \n      income_start_date_year: \n      industry: \n      occupation: \n      education: \n    customer: !ruby/hash:ActiveRecordExt::Encryption::EncryptingHash\n      email: beth.nickeson@hotmail.com\n      credit_report_authorization: \n      marketing_material: \n      electronic_communications_consent: \n      privacy_policy_consent: \n      email_additional_offers: \n    person: !ruby/hash:ActiveRecordExt::Encryption::EncryptingHash\n      first_name: Beth\n      last_name: Nickeson\n      date_of_birth: '1978-09-18'\n      date_of_birth_month: '9'\n      date_of_birth_day: '18'\n      date_of_birth_year: '1978'\n      home_phone: '5807540775'\n      mobile_phone: \n      ssn: |\n        pzg/8sT5bCZg+YLF9640bg==\n    customer_address: !ruby/hash:ActiveRecordExt::Encryption::EncryptingHash\n      address_1: 9703 NS 128 Rd\n      address_2: \n      rent_or_own: \n      monthly_housing_payment: \n      city: Forgan\n      state: OK\n      zip: '73938'\n      military_region: \n      military_address: \n      time_at_address: \n    income: !ruby/hash:ActiveRecordExt::Encryption::EncryptingHash\n      income_type: employment\n      monthly_net_income: '5000.00'\n      additional_household_income: \n      time_at_job: \n      pay_frequency: monthly\n      job_title: \n    customer_consent: !ruby/hash:ActiveRecordExt::Encryption::EncryptingHash\n      nm_consumer_information: \n      il_consumer_information: \n      de_consumer_information: \n      sc_consumer_information: \n    bank_account: !ruby/hash:ActiveRecordExt::Encryption::EncryptingHash\n      routing_number: \n      account_number: \n      account_number_confirmation: \n      account_type: \n    product: !ruby/hash:ActiveRecordExt::Encryption::EncryptingHash\n      payment_method: \n    product_info: !ruby/hash:ActiveRecordExt::Encryption::EncryptingHash\n      selected_loan_amount: \n      selected_loan_apr: \n      selected_loan_term: \n    employer: !ruby/hash:ActiveRecordExt::Encryption::EncryptingHash\n      name: \n      phone_number: \n      phone_number_ext: \n    employer_address: !ruby/hash:ActiveRecordExt::Encryption::EncryptingHash\n      address_1: \n      address_2: \n      city: \n      state: \n      zip: \n    retype_field: !ruby/hash:ActiveRecordExt::Encryption::EncryptingHash\n      retype_ssn: \n:crypt_info:\n  :encrypted_keys:\n  - ssn\n  - bank_account\n  - lead_raw\n  - retype_ssn\n  :salt: 8d5f67e35479eabc87a4c2c3dc72ef1b8f44beef11af386c89be46d77cab6128\n  :iv: |\n    HhinlspiR7gnYOlo5PzsJw==\n  :algorithm: aes-256-cbc\n  :encrypted: true\n  :key_version: 1\n
#
#   stage                                  uuid  contactable  \
# 0  None  d70d4800-4ab9-4a0f-9e31-c3288d83c8e5        False
#
#   cannot_apply_reasons   source  ... last_viewed_stage  status  \
# 0                 None  organic  ...              None  closed
#
#   encrypted_information last_seen_ip application_owner deletion_uuid  \
# 0                  True         None       avantcredit          None
#
#   application_type                 meta_ingested_at meta_ingestion_process_id  \
# 0             None 2024-07-30 22:28:21.701000+00:00                      None
#
#    meta_quarantine_id
# 0                None
#
# [1 rows x 27 columns]
