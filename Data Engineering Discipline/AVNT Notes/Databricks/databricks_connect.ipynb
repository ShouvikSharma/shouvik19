# %%
from databricks import sql
import os

connection = sql.connect(
                        server_hostname = "avant-data-partner01-dev-use2-default.cloud.databricks.com",
                        http_path = "/sql/1.0/warehouses/05d5b5ba0edb9e4a",
                        access_token = "dapif2aab2f9a599ccf50d9b6adec22d1c1d")

cursor = connection.cursor()

cursor.execute("SELECT published_date from silver.marts.credit_card_collections_population_v5 limit 1")
print(cursor.fetchall())

cursor.close()
connection.close()
# Out:
# [Row(published_date=datetime.datetime(2024, 10, 5, 19, 7, 4, 36585, tzinfo=<StaticTzInfo 'Etc/UTC'>))]
